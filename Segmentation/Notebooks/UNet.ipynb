# %% [markdown]
# Problem: **Mask Segmentation Using U-Net** (5 Marks) \
# i. Train a U-Net model for precise segmentation of mask regions in the images. \
# ii. Compare the performance of U-Net with the traditional segmentation method
# using metrics like IoU or Dice score.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!pip install numpy opencv-python tqdm scikit-learn torch torchvision tensorflow

# %%
#pip install keras

# %%
import os
import json
import numpy as np
import cv2
from tqdm import tqdm
from sklearn.model_selection import train_test_split
import torch
from torch.utils.data import Dataset, DataLoader, Subset
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tqdm.keras import TqdmCallback
import tensorflow.keras.backend as K
import random

# %% [markdown]
# # Define Paths & Parameters

# %%
# Set base directory
base_dir = "/content/drive/MyDrive/Segmentation Dataset/1"

# Define sub-directories
cropped_images_dir = os.path.join(base_dir, "face_crop")
segmented_images_dir = os.path.join(base_dir, "face_crop_segmentation")
csv_path = os.path.join(base_dir, "dataset.csv")

# Image dimensions
IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS = 256, 256, 3
BATCH_SIZE = 32

# %%
# Check number of images in directories
num_cropped_images = len([f for f in os.listdir(cropped_images_dir) if f.endswith('.jpg') or f.endswith('.png')])
num_segmented_images = len([f for f in os.listdir(segmented_images_dir) if f.endswith('.jpg') or f.endswith('.png')])

print(f"Number of images in cropped_images_dir: {num_cropped_images}")
print(f"Number of images in segmented_images_dir: {num_segmented_images}")
# Out:
# Number of images in cropped_images_dir: 9452
# Number of images in segmented_images_dir: 9471

# %% [markdown]
# # Map Cropped and Segmented Images

# %%
def map_images(cropped_dir, segmented_dir):
    valid_extensions = ('.jpg', '.jpeg', '.png', '.JPG', '.JPEG', '.PNG')
    cropped_files = [f for f in os.listdir(cropped_dir) if f.endswith(valid_extensions)]
    segmented_files = [f for f in os.listdir(segmented_dir) if f.endswith(valid_extensions)]

    mapped_pairs = []
    for cropped_file in cropped_files:
        base_name, _ = os.path.splitext(cropped_file)
        matched_seg_file = None
        for seg_file in segmented_files:
            if os.path.splitext(seg_file)[0] == base_name:
                matched_seg_file = seg_file
                break
        if matched_seg_file:
            mapped_pairs.append((
                os.path.join(cropped_dir, cropped_file),
                os.path.join(segmented_dir, matched_seg_file)
            ))
    return mapped_pairs

mapped_images = map_images(cropped_images_dir, segmented_images_dir)
print(f" Mapped {len(mapped_images)} image pairs!")
# Save mapped pairs to JSON (if not already saved)
with open("mapped_images.json", "w") as f:
    json.dump(mapped_images, f)
# Out:
# ✅ Mapped 9382 image pairs!

# %% [markdown]
# # Define Custom Dataset for PyTorch DataLoader

# %%
class MaskDataset(Dataset):
    def __init__(self, mapped_images, img_height, img_width):
        self.mapped_images = mapped_images
        self.img_height = img_height
        self.img_width = img_width

    def __len__(self):
        return len(self.mapped_images)

    def __getitem__(self, idx):
        img_path, mask_path = self.mapped_images[idx]
        # Load and resize image
        img = cv2.imread(img_path)
        if img is None:
            raise FileNotFoundError(f"⚠️ Image not found: {img_path}")
        img = cv2.resize(img, (self.img_width, self.img_height))
        img = img.astype(np.float32) / 255.0
        img = np.transpose(img, (2, 0, 1))  # (C, H, W)

        # Load and resize mask
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
        if mask is None:
            raise FileNotFoundError(f"⚠️ Mask not found: {mask_path}")
        mask = cv2.resize(mask, (self.img_width, self.img_height))
        mask = np.where(mask > 0, 1, 0).astype(np.uint8)
        mask = np.expand_dims(mask, axis=0)  # (1, H, W)

        return torch.tensor(img, dtype=torch.float32), torch.tensor(mask, dtype=torch.float32)

# %% [markdown]
# # 4. Load Dataset and Create DataLoaders

# %%
# Set random seed for reproducibility
RANDOM_SEED = 42
random.seed(RANDOM_SEED)

# Load mapped images from JSON
with open("mapped_images.json", "r") as f:
    mapped_images = json.load(f)

# Initialize dataset
dataset = MaskDataset(mapped_images, IMG_HEIGHT, IMG_WIDTH)

# Get all indices
indices = list(range(len(dataset)))

# Split dataset: 70% training, 30% validation
train_indices, val_indices = train_test_split(indices, test_size=0.3, random_state=RANDOM_SEED)

# Create subsets
train_dataset = Subset(dataset, train_indices)
val_dataset = Subset(dataset, val_indices)

# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=4)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=4)

print(f" Data ready! Train size: {len(train_indices)}, Validation size: {len(val_indices)}")
# Out:
# ✅ Data ready! Train size: 6567, Validation size: 2815
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(

# %%
# print(f"X_train shape: {X_train.shape}, Y_train shape: {Y_train.shape}")
# print(f"X_val shape: {X_val.shape}, Y_val shape: {Y_val.shape}")

# %% [markdown]
# ## Build Unet Model

# %%
def build_unet(input_shape=(256, 256, 3)):
    inputs = Input(input_shape)
    # Encoder
    c1 = Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    c1 = Conv2D(64, (3, 3), activation='relu', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = Conv2D(128, (3, 3), activation='relu', padding='same')(p1)
    c2 = Conv2D(128, (3, 3), activation='relu', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = Conv2D(256, (3, 3), activation='relu', padding='same')(p2)
    c3 = Conv2D(256, (3, 3), activation='relu', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    # Bottleneck
    c4 = Conv2D(512, (3, 3), activation='relu', padding='same')(p3)
    c4 = Conv2D(512, (3, 3), activation='relu', padding='same')(c4)

    # Decoder
    u5 = UpSampling2D((2, 2))(c4)
    u5 = concatenate([u5, c3])
    c5 = Conv2D(256, (3, 3), activation='relu', padding='same')(u5)
    c5 = Conv2D(256, (3, 3), activation='relu', padding='same')(c5)

    u6 = UpSampling2D((2, 2))(c5)
    u6 = concatenate([u6, c2])
    c6 = Conv2D(128, (3, 3), activation='relu', padding='same')(u6)
    c6 = Conv2D(128, (3, 3), activation='relu', padding='same')(c6)

    u7 = UpSampling2D((2, 2))(c6)
    u7 = concatenate([u7, c1])
    c7 = Conv2D(64, (3, 3), activation='relu', padding='same')(u7)
    c7 = Conv2D(64, (3, 3), activation='relu', padding='same')(c7)

    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c7)
    model = Model(inputs, outputs)
    return model

# %%
# Define image dimensions and channels
IMG_HEIGHT = 256
IMG_WIDTH = 256
IMG_CHANNELS = 3

# Correct call with input shape
model = build_unet(input_shape=(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 256, 256, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 256, 256, 64)   │          1,792 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 256, 256, 64)   │         36,928 │ conv2d[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 128, 128, 64)   │              0 │ conv2d_1[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 128, 128, 128)  │         73,856 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 128, 128, 128)  │        147,584 │ conv2d_2[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 64, 64, 128)    │              0 │ conv2d_3[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 64, 64, 256)    │        295,168 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 64, 64, 256)    │        590,080 │ conv2d_4[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 32, 32, 256)    │              0 │ conv2d_5[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 32, 32, 512)    │      1,180,160 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 32, 32, 512)    │      2,359,808 │ conv2d_6[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d             │ (None, 64, 64, 512)    │              0 │ conv2d_7[0][0]         │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 64, 64, 768)    │              0 │ up_sampling2d[0][0],   │
# │                           │                        │                │ conv2d_5[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 64, 64, 256)    │      1,769,728 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 64, 64, 256)    │        590,080 │ conv2d_8[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_1           │ (None, 128, 128, 256)  │              0 │ conv2d_9[0][0]         │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 128, 128, 384)  │              0 │ up_sampling2d_1[0][0], │
# │ (Concatenate)             │                        │                │ conv2d_3[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 128, 128, 128)  │        442,496 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 128, 128, 128)  │        147,584 │ conv2d_10[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_2           │ (None, 256, 256, 128)  │              0 │ conv2d_11[0][0]        │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 256, 256, 192)  │              0 │ up_sampling2d_2[0][0], │
# │ (Concatenate)             │                        │                │ conv2d_1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 256, 256, 64)   │        110,656 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_13 (Conv2D)        │ (None, 256, 256, 64)   │         36,928 │ conv2d_12[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_14 (Conv2D)        │ (None, 256, 256, 1)    │             65 │ conv2d_13[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 7,782,913 (29.69 MB)
#  Trainable params: 7,782,913 (29.69 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# # ----------------------------
# # U-Net Model Definition with 3 Encoder and 3 Decoder Layers
# # ----------------------------
# def build_unet(img_height, img_width, img_channels):
#     inputs = Input((img_height, img_width, img_channels))

#     # Encoder
#     c1 = Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
#     c1 = Conv2D(64, (3, 3), activation='relu', padding='same')(c1)
#     p1 = MaxPooling2D((2, 2))(c1)

#     c2 = Conv2D(128, (3, 3), activation='relu', padding='same')(p1)
#     c2 = Conv2D(128, (3, 3), activation='relu', padding='same')(c2)
#     p2 = MaxPooling2D((2, 2))(c2)

#     c3 = Conv2D(256, (3, 3), activation='relu', padding='same')(p2)
#     c3 = Conv2D(256, (3, 3), activation='relu', padding='same')(c3)
#     p3 = MaxPooling2D((2, 2))(c3)

#     # Bottleneck
#     c4 = Conv2D(512, (3, 3), activation='relu', padding='same')(p3)
#     c4 = Conv2D(512, (3, 3), activation='relu', padding='same')(c4)

#     # Decoder
#     u5 = UpSampling2D((2, 2))(c4)
#     u5 = concatenate([u5, c3])
#     c5 = Conv2D(256, (3, 3), activation='relu', padding='same')(u5)
#     c5 = Conv2D(256, (3, 3), activation='relu', padding='same')(c5)

#     u6 = UpSampling2D((2, 2))(c5)
#     u6 = concatenate([u6, c2])
#     c6 = Conv2D(128, (3, 3), activation='relu', padding='same')(u6)
#     c6 = Conv2D(128, (3, 3), activation='relu', padding='same')(c6)

#     u7 = UpSampling2D((2, 2))(c6)
#     u7 = concatenate([u7, c1])
#     c7 = Conv2D(64, (3, 3), activation='relu', padding='same')(u7)
#     c7 = Conv2D(64, (3, 3), activation='relu', padding='same')(c7)

#     # Output Layer
#     outputs = Conv2D(1, (1, 1), activation='sigmoid')(c7)

#     model = Model(inputs=[inputs], outputs=[outputs])
#     return model

# # Build U-Net
# model = build_unet(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)
# #model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])
# model.summary()

# %% [markdown]
# # 6. Define Combined Loss: Dice Loss + Binary Cross-Entropy

# %%
def dice_coefficient(y_true, y_pred, smooth=1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_loss(y_true, y_pred):
    return 1 - dice_coefficient(y_true, y_pred)

def combined_loss(y_true, y_pred):
    bce = tf.keras.losses.BinaryCrossentropy()(y_true, y_pred)
    return 0.5 * bce + 0.5 * dice_loss(y_true, y_pred)

model.compile(optimizer=Adam(learning_rate=1e-4),
              loss=combined_loss,
              metrics=[dice_coefficient])

# %% [markdown]
# # 7. Convert DataLoader Batch to Numpy Arrays for Training

# %% [markdown]
# # Create a Generator from PyTorch DataLoader

# %%
def data_generator(loader):
    """
    Generator that yields batches from a PyTorch DataLoader.
    It converts the batch (in shape (batch, channels, height, width))
    to the shape TensorFlow expects: (batch, height, width, channels).
    """
    while True:  # Loop indefinitely (fit() will control number of epochs/steps)
        for batch in loader:
            X_batch, Y_batch = batch
            # Convert PyTorch tensor (C, H, W) to NumPy array in (H, W, C)
            X_batch = X_batch.numpy().transpose(0, 2, 3, 1)
            Y_batch = Y_batch.numpy().transpose(0, 2, 3, 1)
            yield X_batch, Y_batch

# Determine steps per epoch and validation steps
steps_per_epoch = len(train_loader)
validation_steps = len(val_loader)

# %% [markdown]
# # 8. Define Callbacks: Early Stopping & Learning Rate Scheduler

# %%
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    verbose=1
)
lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-6,
    verbose=1
)

# %% [markdown]
# # 9. Train the Model using the Generator

# %%
# EPOCHS = 50  # Increase epochs as needed

# history = model.fit(
#     data_generator(train_loader),
#     steps_per_epoch=steps_per_epoch,
#     validation_data=data_generator(val_loader),
#     validation_steps=validation_steps,
#     epochs=EPOCHS,
#     callbacks=[early_stopping, lr_scheduler, TqdmCallback(verbose=1)],
#     verbose=1  # Disable default logging; TqdmCallback shows progress
# )

# # Save the trained model
# model.save(os.path.join(base_dir, "unet_model.h5"))
# print(" Model training complete and saved!")

# %%
import os

# %%
def load_trained_model(model_path):
    """
    Loads the trained model from disk along with custom objects.

    Parameters:
        model_path (str): Path to the saved model file (e.g., "unet_model.h5")

    Returns:
        model (tf.keras.Model): Loaded Keras model.
    """
    # Define custom objects: combined_loss and dice_coefficient need to be passed
    custom_objects = {
        'combined_loss': combined_loss,
        'dice_coefficient': dice_coefficient
    }

    # Load and return the model
    model = tf.keras.models.load_model(model_path, custom_objects=custom_objects)
    print(f" Model loaded from {model_path}")
    return model

# Example usage:
model = load_trained_model(os.path.join(base_dir, "unet_model.h5"))
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ✅ Model loaded from /content/drive/MyDrive/Segmentation Dataset/1/unet_model.h5

# %%
# # ----------------------------
# # Model Training
# # ----------------------------
# EPOCHS = 25
# BATCH_SIZE = 32

# # Convert data to numpy for TensorFlow training
# X_train, Y_train = next(iter(train_loader))
# X_val, Y_val = next(iter(val_loader))

# X_train = X_train.numpy().transpose(0, 2, 3, 1)
# Y_train = Y_train.numpy().transpose(0, 2, 3, 1)
# X_val = X_val.numpy().transpose(0, 2, 3, 1)
# Y_val = Y_val.numpy().transpose(0, 2, 3, 1)

# # Train U-Net
# history = model.fit(
#     X_train, Y_train,
#     validation_data=(X_val, Y_val),
#     batch_size=BATCH_SIZE,
#     epochs=EPOCHS,
#     verbose=1
# )

# # Save trained model
# model.save(os.path.join(base_dir, "unet_model.h5"))
# print("✅ Model training complete and saved!")

# %%
# # ----------------------------
# # IoU and Dice Score Calculation
# # ----------------------------
# def iou(y_true, y_pred):
#     intersection = np.logical_and(y_true, y_pred).sum()
#     union = np.logical_or(y_true, y_pred).sum()
#     return intersection / union if union != 0 else 0

# def dice_score(y_true, y_pred):
#     intersection = np.logical_and(y_true, y_pred).sum()
#     return (2.0 * intersection) / (y_true.sum() + y_pred.sum())

# # Evaluate on validation data
# preds = model.predict(X_val)
# preds_binary = (preds > 0.5).astype(np.uint8)

# ious, dices = [], []
# for i in range(len(Y_val)):
#     ious.append(iou(Y_val[i], preds_binary[i]))
#     dices.append(dice_score)

# %% [markdown]
# fnkwndiwnfo

# %%
# ----------------------------
# Evaluation on the Entire Validation Set
# ----------------------------



# Initialize lists to collect predictions and ground truth masks
all_preds = []
all_Y_val = []

# Determine the number of validation steps (batches)
print(f"Evaluating on {validation_steps} validation batches...")

# Iterate over the validation DataLoader
for _ in range(validation_steps):
    X_batch, Y_batch = next(data_generator(val_loader))
    preds_batch = model.predict(X_batch)
    preds_binary_batch = (preds_batch > 0.5).astype(np.uint8)
    all_preds.append(preds_binary_batch)
    all_Y_val.append(Y_batch)

# Concatenate all batches into single arrays
all_preds = np.concatenate(all_preds, axis=0)
all_Y_val = np.concatenate(all_Y_val, axis=0)

# Define IoU and Dice functions
def iou(y_true, y_pred):
    intersection = np.logical_and(y_true, y_pred).sum()
    union = np.logical_or(y_true, y_pred).sum()
    return intersection / union if union != 0 else 0

def dice_score(y_true, y_pred):
    intersection = np.logical_and(y_true, y_pred).sum()
    return (2.0 * intersection) / (y_true.sum() + y_pred.sum() + 1e-7)

# Calculate IoU and Dice Score for each sample in the validation set
iou_scores = []
dice_scores = []
for i in range(len(all_Y_val)):
    iou_scores.append(iou(all_Y_val[i], all_preds[i]))
    dice_scores.append(dice_score(all_Y_val[i], all_preds[i]))

# Print the evaluation results
print(f"✅ Mean IoU: {np.mean(iou_scores):.4f}")
print(f"✅ Mean Dice Score: {np.mean(dice_scores):.4f}")

# Optionally, print per-sample scores
for i, (iou_val, dice_val) in enumerate(zip(iou_scores, dice_scores)):
    print(f"Sample {i+1:3d} - IoU: {iou_val:.4f}, Dice: {dice_val:.4f}")
# Out:
# Evaluating on 88 validation batches...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 55s 55s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 52s 52s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 52s 52s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 53s 53s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 53s 53s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 51s 51s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 51s 51s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 51s 51s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 59s 59s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 55s 55s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 53s 53s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 53s 53s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 53s 53s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 53s 53s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 53s 53s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 51s 51s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 62s 62s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 55s 55s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 52s 52s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 51s 51s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 53s 53s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 53s 53s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 53s 53s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 62s 62s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 53s 53s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 52s 52s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 53s 53s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 53s 53s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 53s 53s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 52s 52s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 51s 51s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 61s 61s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 53s 53s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 53s 53s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 52s 52s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 52s 52s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 50s 50s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 52s 52s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 52s 52s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 62s 62s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 53s 53s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 51s 51s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 51s 51s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 52s 52s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 52s 52s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 50s 50s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 59s 59s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 50s 50s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 52s 52s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 52s 52s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 52s 52s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 50s 50s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 52s 52s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 61s 61s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 52s 52s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 51s 51s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 50s 50s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 52s 52s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 52s 52s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 51s 51s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 50s 50s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 52s 52s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 56s 56s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 52s 52s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 50s 50s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 51s 51s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 50s 50s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 52s 52s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 53s 53s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 59s 59s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 53s 53s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 52s 52s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 51s 51s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 52s 52s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 53s 53s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 52s 52s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 64s 64s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 52s 52s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 51s 51s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 52s 52s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 52s 52s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 52s 52s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 52s 52s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 52s 52s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 56s 56s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 52s 52s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 51s 51s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 52s 52s/step
# ✅ Mean IoU: 0.8685
# ✅ Mean Dice Score: 0.9238
# Sample   1 - IoU: 0.8298, Dice: 0.9070
# Sample   2 - IoU: 0.9391, Dice: 0.9686
# Sample   3 - IoU: 0.9470, Dice: 0.9728
# Sample   4 - IoU: 0.8389, Dice: 0.9124
# Sample   5 - IoU: 0.6035, Dice: 0.7527
# Sample   6 - IoU: 0.9488, Dice: 0.9737
# Sample   7 - IoU: 0.9428, Dice: 0.9706
# Sample   8 - IoU: 0.8567, Dice: 0.9228
# Sample   9 - IoU: 0.9054, Dice: 0.9504
# Sample  10 - IoU: 0.8836, Dice: 0.9382
# Sample  11 - IoU: 0.6395, Dice: 0.7801
# Sample  12 - IoU: 0.9483, Dice: 0.9734
# Sample  13 - IoU: 0.8546, Dice: 0.9216
# Sample  14 - IoU: 0.8436, Dice: 0.9152
# Sample  15 - IoU: 0.8550, Dice: 0.9218
# Sample  16 - IoU: 0.9738, Dice: 0.9867
# Sample  17 - IoU: 0.9697, Dice: 0.9846
# Sample  18 - IoU: 0.9191, Dice: 0.9578
# Sample  19 - IoU: 0.9706, Dice: 0.9851
# Sample  20 - IoU: 0.9256, Dice: 0.9614
# Sample  21 - IoU: 0.3931, Dice: 0.5644
# Sample  22 - IoU: 0.8401, Dice: 0.9131
# Sample  23 - IoU: 0.8828, Dice: 0.9378
# Sample  24 - IoU: 0.6675, Dice: 0.8006
# Sample  25 - IoU: 0.9465, Dice: 0.9725
# Sample  26 - IoU: 0.9258, Dice: 0.9615
# Sample  27 - IoU: 0.9477, Dice: 0.9732
# Sample  28 - IoU: 0.9092, Dice: 0.9525
# Sample  29 - IoU: 0.9581, Dice: 0.9786
# Sample  30 - IoU: 0.9607, Dice: 0.9800
# Sample  31 - IoU: 0.7925, Dice: 0.8842
# Sample  32 - IoU: 0.9717, Dice: 0.9857
# Sample  33 - IoU: 0.8298, Dice: 0.9070
# Sample  34 - IoU: 0.9391, Dice: 0.9686
# Sample  35 - IoU: 0.9470, Dice: 0.9728
# Sample  36 - IoU: 0.8389, Dice: 0.9124
# Sample  37 - IoU: 0.6035, Dice: 0.7527
# Sample  38 - IoU: 0.9488, Dice: 0.9737
# Sample  39 - IoU: 0.9428, Dice: 0.9706
# Sample  40 - IoU: 0.8567, Dice: 0.9228
# Sample  41 - IoU: 0.9054, Dice: 0.9504
# Sample  42 - IoU: 0.8836, Dice: 0.9382
# Sample  43 - IoU: 0.6395, Dice: 0.7801
# Sample  44 - IoU: 0.9483, Dice: 0.9734
# Sample  45 - IoU: 0.8546, Dice: 0.9216
# Sample  46 - IoU: 0.8436, Dice: 0.9152
# Sample  47 - IoU: 0.8550, Dice: 0.9218
# Sample  48 - IoU: 0.9738, Dice: 0.9867
# Sample  49 - IoU: 0.9697, Dice: 0.9846
# Sample  50 - IoU: 0.9191, Dice: 0.9578
# Sample  51 - IoU: 0.9706, Dice: 0.9851
# Sample  52 - IoU: 0.9256, Dice: 0.9614
# Sample  53 - IoU: 0.3931, Dice: 0.5644
# Sample  54 - IoU: 0.8401, Dice: 0.9131
# Sample  55 - IoU: 0.8828, Dice: 0.9378
# Sample  56 - IoU: 0.6675, Dice: 0.8006
# Sample  57 - IoU: 0.9465, Dice: 0.9725
# Sample  58 - IoU: 0.9258, Dice: 0.9615
# Sample  59 - IoU: 0.9477, Dice: 0.9732
# Sample  60 - IoU: 0.9092, Dice: 0.9525
# Sample  61 - IoU: 0.9581, Dice: 0.9786
# Sample  62 - IoU: 0.9607, Dice: 0.9800
# Sample  63 - IoU: 0.7925, Dice: 0.8842
# Sample  64 - IoU: 0.9717, Dice: 0.9857
# Sample  65 - IoU: 0.8298, Dice: 0.9070
# Sample  66 - IoU: 0.9391, Dice: 0.9686
# Sample  67 - IoU: 0.9470, Dice: 0.9728
# Sample  68 - IoU: 0.8389, Dice: 0.9124
# Sample  69 - IoU: 0.6035, Dice: 0.7527
# Sample  70 - IoU: 0.9488, Dice: 0.9737
# Sample  71 - IoU: 0.9428, Dice: 0.9706
# Sample  72 - IoU: 0.8567, Dice: 0.9228
# Sample  73 - IoU: 0.9054, Dice: 0.9504
# Sample  74 - IoU: 0.8836, Dice: 0.9382
# Sample  75 - IoU: 0.6395, Dice: 0.7801
# Sample  76 - IoU: 0.9483, Dice: 0.9734
# Sample  77 - IoU: 0.8546, Dice: 0.9216
# Sample  78 - IoU: 0.8436, Dice: 0.9152
# Sample  79 - IoU: 0.8550, Dice: 0.9218
# Sample  80 - IoU: 0.9738, Dice: 0.9867
# Sample  81 - IoU: 0.9697, Dice: 0.9846
# Sample  82 - IoU: 0.9191, Dice: 0.9578
# Sample  83 - IoU: 0.9706, Dice: 0.9851
# Sample  84 - IoU: 0.9256, Dice: 0.9614
# Sample  85 - IoU: 0.3931, Dice: 0.5644
# Sample  86 - IoU: 0.8401, Dice: 0.9131
# Sample  87 - IoU: 0.8828, Dice: 0.9378
# Sample  88 - IoU: 0.6675, Dice: 0.8006
# Sample  89 - IoU: 0.9465, Dice: 0.9725
# Sample  90 - IoU: 0.9258, Dice: 0.9615
# Sample  91 - IoU: 0.9477, Dice: 0.9732
# Sample  92 - IoU: 0.9092, Dice: 0.9525
# Sample  93 - IoU: 0.9581, Dice: 0.9786
# Sample  94 - IoU: 0.9607, Dice: 0.9800
# Sample  95 - IoU: 0.7925, Dice: 0.8842
# Sample  96 - IoU: 0.9717, Dice: 0.9857
# Sample  97 - IoU: 0.8298, Dice: 0.9070
# Sample  98 - IoU: 0.9391, Dice: 0.9686
# Sample  99 - IoU: 0.9470, Dice: 0.9728
# Sample 100 - IoU: 0.8389, Dice: 0.9124
# Sample 101 - IoU: 0.6035, Dice: 0.7527
# Sample 102 - IoU: 0.9488, Dice: 0.9737
# Sample 103 - IoU: 0.9428, Dice: 0.9706
# Sample 104 - IoU: 0.8567, Dice: 0.9228
# Sample 105 - IoU: 0.9054, Dice: 0.9504
# Sample 106 - IoU: 0.8836, Dice: 0.9382
# Sample 107 - IoU: 0.6395, Dice: 0.7801
# Sample 108 - IoU: 0.9483, Dice: 0.9734
# Sample 109 - IoU: 0.8546, Dice: 0.9216
# Sample 110 - IoU: 0.8436, Dice: 0.9152
# Sample 111 - IoU: 0.8550, Dice: 0.9218
# Sample 112 - IoU: 0.9738, Dice: 0.9867
# Sample 113 - IoU: 0.9697, Dice: 0.9846
# Sample 114 - IoU: 0.9191, Dice: 0.9578
# Sample 115 - IoU: 0.9706, Dice: 0.9851
# Sample 116 - IoU: 0.9256, Dice: 0.9614
# Sample 117 - IoU: 0.3931, Dice: 0.5644
# Sample 118 - IoU: 0.8401, Dice: 0.9131
# Sample 119 - IoU: 0.8828, Dice: 0.9378
# Sample 120 - IoU: 0.6675, Dice: 0.8006
# Sample 121 - IoU: 0.9465, Dice: 0.9725
# Sample 122 - IoU: 0.9258, Dice: 0.9615
# Sample 123 - IoU: 0.9477, Dice: 0.9732
# Sample 124 - IoU: 0.9092, Dice: 0.9525
# Sample 125 - IoU: 0.9581, Dice: 0.9786
# Sample 126 - IoU: 0.9607, Dice: 0.9800
# Sample 127 - IoU: 0.7925, Dice: 0.8842
# Sample 128 - IoU: 0.9717, Dice: 0.9857
# Sample 129 - IoU: 0.8298, Dice: 0.9070
# Sample 130 - IoU: 0.9391, Dice: 0.9686
# Sample 131 - IoU: 0.9470, Dice: 0.9728
# Sample 132 - IoU: 0.8389, Dice: 0.9124
# Sample 133 - IoU: 0.6035, Dice: 0.7527
# Sample 134 - IoU: 0.9488, Dice: 0.9737
# Sample 135 - IoU: 0.9428, Dice: 0.9706
# Sample 136 - IoU: 0.8567, Dice: 0.9228
# Sample 137 - IoU: 0.9054, Dice: 0.9504
# Sample 138 - IoU: 0.8836, Dice: 0.9382
# Sample 139 - IoU: 0.6395, Dice: 0.7801
# Sample 140 - IoU: 0.9483, Dice: 0.9734
# Sample 141 - IoU: 0.8546, Dice: 0.9216
# Sample 142 - IoU: 0.8436, Dice: 0.9152
# Sample 143 - IoU: 0.8550, Dice: 0.9218
# Sample 144 - IoU: 0.9738, Dice: 0.9867
# Sample 145 - IoU: 0.9697, Dice: 0.9846
# Sample 146 - IoU: 0.9191, Dice: 0.9578
# Sample 147 - IoU: 0.9706, Dice: 0.9851
# Sample 148 - IoU: 0.9256, Dice: 0.9614
# Sample 149 - IoU: 0.3931, Dice: 0.5644
# Sample 150 - IoU: 0.8401, Dice: 0.9131
# Sample 151 - IoU: 0.8828, Dice: 0.9378
# Sample 152 - IoU: 0.6675, Dice: 0.8006
# Sample 153 - IoU: 0.9465, Dice: 0.9725
# Sample 154 - IoU: 0.9258, Dice: 0.9615
# Sample 155 - IoU: 0.9477, Dice: 0.9732
# Sample 156 - IoU: 0.9092, Dice: 0.9525
# Sample 157 - IoU: 0.9581, Dice: 0.9786
# Sample 158 - IoU: 0.9607, Dice: 0.9800
# Sample 159 - IoU: 0.7925, Dice: 0.8842
# Sample 160 - IoU: 0.9717, Dice: 0.9857
# Sample 161 - IoU: 0.8298, Dice: 0.9070
# Sample 162 - IoU: 0.9391, Dice: 0.9686
# Sample 163 - IoU: 0.9470, Dice: 0.9728
# Sample 164 - IoU: 0.8389, Dice: 0.9124
# Sample 165 - IoU: 0.6035, Dice: 0.7527
# Sample 166 - IoU: 0.9488, Dice: 0.9737
# Sample 167 - IoU: 0.9428, Dice: 0.9706
# Sample 168 - IoU: 0.8567, Dice: 0.9228
# Sample 169 - IoU: 0.9054, Dice: 0.9504
# Sample 170 - IoU: 0.8836, Dice: 0.9382
# Sample 171 - IoU: 0.6395, Dice: 0.7801
# Sample 172 - IoU: 0.9483, Dice: 0.9734
# Sample 173 - IoU: 0.8546, Dice: 0.9216
# Sample 174 - IoU: 0.8436, Dice: 0.9152
# Sample 175 - IoU: 0.8550, Dice: 0.9218
# Sample 176 - IoU: 0.9738, Dice: 0.9867
# Sample 177 - IoU: 0.9697, Dice: 0.9846
# Sample 178 - IoU: 0.9191, Dice: 0.9578
# Sample 179 - IoU: 0.9706, Dice: 0.9851
# Sample 180 - IoU: 0.9256, Dice: 0.9614
# Sample 181 - IoU: 0.3931, Dice: 0.5644
# Sample 182 - IoU: 0.8401, Dice: 0.9131
# Sample 183 - IoU: 0.8828, Dice: 0.9378
# Sample 184 - IoU: 0.6675, Dice: 0.8006
# Sample 185 - IoU: 0.9465, Dice: 0.9725
# Sample 186 - IoU: 0.9258, Dice: 0.9615
# Sample 187 - IoU: 0.9477, Dice: 0.9732
# Sample 188 - IoU: 0.9092, Dice: 0.9525
# Sample 189 - IoU: 0.9581, Dice: 0.9786
# Sample 190 - IoU: 0.9607, Dice: 0.9800
# Sample 191 - IoU: 0.7925, Dice: 0.8842
# Sample 192 - IoU: 0.9717, Dice: 0.9857
# Sample 193 - IoU: 0.8298, Dice: 0.9070
# Sample 194 - IoU: 0.9391, Dice: 0.9686
# Sample 195 - IoU: 0.9470, Dice: 0.9728
# Sample 196 - IoU: 0.8389, Dice: 0.9124
# Sample 197 - IoU: 0.6035, Dice: 0.7527
# Sample 198 - IoU: 0.9488, Dice: 0.9737
# Sample 199 - IoU: 0.9428, Dice: 0.9706
# Sample 200 - IoU: 0.8567, Dice: 0.9228
# Sample 201 - IoU: 0.9054, Dice: 0.9504
# Sample 202 - IoU: 0.8836, Dice: 0.9382
# Sample 203 - IoU: 0.6395, Dice: 0.7801
# Sample 204 - IoU: 0.9483, Dice: 0.9734
# Sample 205 - IoU: 0.8546, Dice: 0.9216
# Sample 206 - IoU: 0.8436, Dice: 0.9152
# Sample 207 - IoU: 0.8550, Dice: 0.9218
# Sample 208 - IoU: 0.9738, Dice: 0.9867
# Sample 209 - IoU: 0.9697, Dice: 0.9846
# Sample 210 - IoU: 0.9191, Dice: 0.9578
# Sample 211 - IoU: 0.9706, Dice: 0.9851
# Sample 212 - IoU: 0.9256, Dice: 0.9614
# Sample 213 - IoU: 0.3931, Dice: 0.5644
# Sample 214 - IoU: 0.8401, Dice: 0.9131
# Sample 215 - IoU: 0.8828, Dice: 0.9378
# Sample 216 - IoU: 0.6675, Dice: 0.8006
# Sample 217 - IoU: 0.9465, Dice: 0.9725
# Sample 218 - IoU: 0.9258, Dice: 0.9615
# Sample 219 - IoU: 0.9477, Dice: 0.9732
# Sample 220 - IoU: 0.9092, Dice: 0.9525
# Sample 221 - IoU: 0.9581, Dice: 0.9786
# Sample 222 - IoU: 0.9607, Dice: 0.9800
# Sample 223 - IoU: 0.7925, Dice: 0.8842
# Sample 224 - IoU: 0.9717, Dice: 0.9857
# Sample 225 - IoU: 0.8298, Dice: 0.9070
# Sample 226 - IoU: 0.9391, Dice: 0.9686
# Sample 227 - IoU: 0.9470, Dice: 0.9728
# Sample 228 - IoU: 0.8389, Dice: 0.9124
# Sample 229 - IoU: 0.6035, Dice: 0.7527
# Sample 230 - IoU: 0.9488, Dice: 0.9737
# Sample 231 - IoU: 0.9428, Dice: 0.9706
# Sample 232 - IoU: 0.8567, Dice: 0.9228
# Sample 233 - IoU: 0.9054, Dice: 0.9504
# Sample 234 - IoU: 0.8836, Dice: 0.9382
# Sample 235 - IoU: 0.6395, Dice: 0.7801
# Sample 236 - IoU: 0.9483, Dice: 0.9734
# Sample 237 - IoU: 0.8546, Dice: 0.9216
# Sample 238 - IoU: 0.8436, Dice: 0.9152
# Sample 239 - IoU: 0.8550, Dice: 0.9218
# Sample 240 - IoU: 0.9738, Dice: 0.9867
# Sample 241 - IoU: 0.9697, Dice: 0.9846
# Sample 242 - IoU: 0.9191, Dice: 0.9578
# Sample 243 - IoU: 0.9706, Dice: 0.9851
# Sample 244 - IoU: 0.9256, Dice: 0.9614
# Sample 245 - IoU: 0.3931, Dice: 0.5644
# Sample 246 - IoU: 0.8401, Dice: 0.9131
# Sample 247 - IoU: 0.8828, Dice: 0.9378
# Sample 248 - IoU: 0.6675, Dice: 0.8006
# Sample 249 - IoU: 0.9465, Dice: 0.9725
# Sample 250 - IoU: 0.9258, Dice: 0.9615
# Sample 251 - IoU: 0.9477, Dice: 0.9732
# Sample 252 - IoU: 0.9092, Dice: 0.9525
# Sample 253 - IoU: 0.9581, Dice: 0.9786
# Sample 254 - IoU: 0.9607, Dice: 0.9800
# Sample 255 - IoU: 0.7925, Dice: 0.8842
# Sample 256 - IoU: 0.9717, Dice: 0.9857
# Sample 257 - IoU: 0.8298, Dice: 0.9070
# Sample 258 - IoU: 0.9391, Dice: 0.9686
# Sample 259 - IoU: 0.9470, Dice: 0.9728
# Sample 260 - IoU: 0.8389, Dice: 0.9124
# Sample 261 - IoU: 0.6035, Dice: 0.7527
# Sample 262 - IoU: 0.9488, Dice: 0.9737
# Sample 263 - IoU: 0.9428, Dice: 0.9706
# Sample 264 - IoU: 0.8567, Dice: 0.9228
# Sample 265 - IoU: 0.9054, Dice: 0.9504
# Sample 266 - IoU: 0.8836, Dice: 0.9382
# Sample 267 - IoU: 0.6395, Dice: 0.7801
# Sample 268 - IoU: 0.9483, Dice: 0.9734
# Sample 269 - IoU: 0.8546, Dice: 0.9216
# Sample 270 - IoU: 0.8436, Dice: 0.9152
# Sample 271 - IoU: 0.8550, Dice: 0.9218
# Sample 272 - IoU: 0.9738, Dice: 0.9867
# Sample 273 - IoU: 0.9697, Dice: 0.9846
# Sample 274 - IoU: 0.9191, Dice: 0.9578
# Sample 275 - IoU: 0.9706, Dice: 0.9851
# Sample 276 - IoU: 0.9256, Dice: 0.9614
# Sample 277 - IoU: 0.3931, Dice: 0.5644
# Sample 278 - IoU: 0.8401, Dice: 0.9131
# Sample 279 - IoU: 0.8828, Dice: 0.9378
# Sample 280 - IoU: 0.6675, Dice: 0.8006
# Sample 281 - IoU: 0.9465, Dice: 0.9725
# Sample 282 - IoU: 0.9258, Dice: 0.9615
# Sample 283 - IoU: 0.9477, Dice: 0.9732
# Sample 284 - IoU: 0.9092, Dice: 0.9525
# Sample 285 - IoU: 0.9581, Dice: 0.9786
# Sample 286 - IoU: 0.9607, Dice: 0.9800
# Sample 287 - IoU: 0.7925, Dice: 0.8842
# Sample 288 - IoU: 0.9717, Dice: 0.9857
# Sample 289 - IoU: 0.8298, Dice: 0.9070
# Sample 290 - IoU: 0.9391, Dice: 0.9686
# Sample 291 - IoU: 0.9470, Dice: 0.9728
# Sample 292 - IoU: 0.8389, Dice: 0.9124
# Sample 293 - IoU: 0.6035, Dice: 0.7527
# Sample 294 - IoU: 0.9488, Dice: 0.9737
# Sample 295 - IoU: 0.9428, Dice: 0.9706
# Sample 296 - IoU: 0.8567, Dice: 0.9228
# Sample 297 - IoU: 0.9054, Dice: 0.9504
# Sample 298 - IoU: 0.8836, Dice: 0.9382
# Sample 299 - IoU: 0.6395, Dice: 0.7801
# Sample 300 - IoU: 0.9483, Dice: 0.9734
# Sample 301 - IoU: 0.8546, Dice: 0.9216
# Sample 302 - IoU: 0.8436, Dice: 0.9152
# Sample 303 - IoU: 0.8550, Dice: 0.9218
# Sample 304 - IoU: 0.9738, Dice: 0.9867
# Sample 305 - IoU: 0.9697, Dice: 0.9846
# Sample 306 - IoU: 0.9191, Dice: 0.9578
# Sample 307 - IoU: 0.9706, Dice: 0.9851
# Sample 308 - IoU: 0.9256, Dice: 0.9614
# Sample 309 - IoU: 0.3931, Dice: 0.5644
# Sample 310 - IoU: 0.8401, Dice: 0.9131
# Sample 311 - IoU: 0.8828, Dice: 0.9378
# Sample 312 - IoU: 0.6675, Dice: 0.8006
# Sample 313 - IoU: 0.9465, Dice: 0.9725
# Sample 314 - IoU: 0.9258, Dice: 0.9615
# Sample 315 - IoU: 0.9477, Dice: 0.9732
# Sample 316 - IoU: 0.9092, Dice: 0.9525
# Sample 317 - IoU: 0.9581, Dice: 0.9786
# Sample 318 - IoU: 0.9607, Dice: 0.9800
# Sample 319 - IoU: 0.7925, Dice: 0.8842
# Sample 320 - IoU: 0.9717, Dice: 0.9857
# Sample 321 - IoU: 0.8298, Dice: 0.9070
# Sample 322 - IoU: 0.9391, Dice: 0.9686
# Sample 323 - IoU: 0.9470, Dice: 0.9728
# Sample 324 - IoU: 0.8389, Dice: 0.9124
# Sample 325 - IoU: 0.6035, Dice: 0.7527
# Sample 326 - IoU: 0.9488, Dice: 0.9737
# Sample 327 - IoU: 0.9428, Dice: 0.9706
# Sample 328 - IoU: 0.8567, Dice: 0.9228
# Sample 329 - IoU: 0.9054, Dice: 0.9504
# Sample 330 - IoU: 0.8836, Dice: 0.9382
# Sample 331 - IoU: 0.6395, Dice: 0.7801
# Sample 332 - IoU: 0.9483, Dice: 0.9734
# Sample 333 - IoU: 0.8546, Dice: 0.9216
# Sample 334 - IoU: 0.8436, Dice: 0.9152
# Sample 335 - IoU: 0.8550, Dice: 0.9218
# Sample 336 - IoU: 0.9738, Dice: 0.9867
# Sample 337 - IoU: 0.9697, Dice: 0.9846
# Sample 338 - IoU: 0.9191, Dice: 0.9578
# Sample 339 - IoU: 0.9706, Dice: 0.9851
# Sample 340 - IoU: 0.9256, Dice: 0.9614
# Sample 341 - IoU: 0.3931, Dice: 0.5644
# Sample 342 - IoU: 0.8401, Dice: 0.9131
# Sample 343 - IoU: 0.8828, Dice: 0.9378
# Sample 344 - IoU: 0.6675, Dice: 0.8006
# Sample 345 - IoU: 0.9465, Dice: 0.9725
# Sample 346 - IoU: 0.9258, Dice: 0.9615
# Sample 347 - IoU: 0.9477, Dice: 0.9732
# Sample 348 - IoU: 0.9092, Dice: 0.9525
# Sample 349 - IoU: 0.9581, Dice: 0.9786
# Sample 350 - IoU: 0.9607, Dice: 0.9800
# Sample 351 - IoU: 0.7925, Dice: 0.8842
# Sample 352 - IoU: 0.9717, Dice: 0.9857
# Sample 353 - IoU: 0.8298, Dice: 0.9070
# Sample 354 - IoU: 0.9391, Dice: 0.9686
# Sample 355 - IoU: 0.9470, Dice: 0.9728
# Sample 356 - IoU: 0.8389, Dice: 0.9124
# Sample 357 - IoU: 0.6035, Dice: 0.7527
# Sample 358 - IoU: 0.9488, Dice: 0.9737
# Sample 359 - IoU: 0.9428, Dice: 0.9706
# Sample 360 - IoU: 0.8567, Dice: 0.9228
# Sample 361 - IoU: 0.9054, Dice: 0.9504
# Sample 362 - IoU: 0.8836, Dice: 0.9382
# Sample 363 - IoU: 0.6395, Dice: 0.7801
# Sample 364 - IoU: 0.9483, Dice: 0.9734
# Sample 365 - IoU: 0.8546, Dice: 0.9216
# Sample 366 - IoU: 0.8436, Dice: 0.9152
# Sample 367 - IoU: 0.8550, Dice: 0.9218
# Sample 368 - IoU: 0.9738, Dice: 0.9867
# Sample 369 - IoU: 0.9697, Dice: 0.9846
# Sample 370 - IoU: 0.9191, Dice: 0.9578
# Sample 371 - IoU: 0.9706, Dice: 0.9851
# Sample 372 - IoU: 0.9256, Dice: 0.9614
# Sample 373 - IoU: 0.3931, Dice: 0.5644
# Sample 374 - IoU: 0.8401, Dice: 0.9131
# Sample 375 - IoU: 0.8828, Dice: 0.9378
# Sample 376 - IoU: 0.6675, Dice: 0.8006
# Sample 377 - IoU: 0.9465, Dice: 0.9725
# Sample 378 - IoU: 0.9258, Dice: 0.9615
# Sample 379 - IoU: 0.9477, Dice: 0.9732
# Sample 380 - IoU: 0.9092, Dice: 0.9525
# Sample 381 - IoU: 0.9581, Dice: 0.9786
# Sample 382 - IoU: 0.9607, Dice: 0.9800
# Sample 383 - IoU: 0.7925, Dice: 0.8842
# Sample 384 - IoU: 0.9717, Dice: 0.9857
# Sample 385 - IoU: 0.8298, Dice: 0.9070
# Sample 386 - IoU: 0.9391, Dice: 0.9686
# Sample 387 - IoU: 0.9470, Dice: 0.9728
# Sample 388 - IoU: 0.8389, Dice: 0.9124
# Sample 389 - IoU: 0.6035, Dice: 0.7527
# Sample 390 - IoU: 0.9488, Dice: 0.9737
# Sample 391 - IoU: 0.9428, Dice: 0.9706
# Sample 392 - IoU: 0.8567, Dice: 0.9228
# Sample 393 - IoU: 0.9054, Dice: 0.9504
# Sample 394 - IoU: 0.8836, Dice: 0.9382
# Sample 395 - IoU: 0.6395, Dice: 0.7801
# Sample 396 - IoU: 0.9483, Dice: 0.9734
# Sample 397 - IoU: 0.8546, Dice: 0.9216
# Sample 398 - IoU: 0.8436, Dice: 0.9152
# Sample 399 - IoU: 0.8550, Dice: 0.9218
# Sample 400 - IoU: 0.9738, Dice: 0.9867
# Sample 401 - IoU: 0.9697, Dice: 0.9846
# Sample 402 - IoU: 0.9191, Dice: 0.9578
# Sample 403 - IoU: 0.9706, Dice: 0.9851
# Sample 404 - IoU: 0.9256, Dice: 0.9614
# Sample 405 - IoU: 0.3931, Dice: 0.5644
# Sample 406 - IoU: 0.8401, Dice: 0.9131
# Sample 407 - IoU: 0.8828, Dice: 0.9378
# Sample 408 - IoU: 0.6675, Dice: 0.8006
# Sample 409 - IoU: 0.9465, Dice: 0.9725
# Sample 410 - IoU: 0.9258, Dice: 0.9615
# Sample 411 - IoU: 0.9477, Dice: 0.9732
# Sample 412 - IoU: 0.9092, Dice: 0.9525
# Sample 413 - IoU: 0.9581, Dice: 0.9786
# Sample 414 - IoU: 0.9607, Dice: 0.9800
# Sample 415 - IoU: 0.7925, Dice: 0.8842
# Sample 416 - IoU: 0.9717, Dice: 0.9857
# Sample 417 - IoU: 0.8298, Dice: 0.9070
# Sample 418 - IoU: 0.9391, Dice: 0.9686
# Sample 419 - IoU: 0.9470, Dice: 0.9728
# Sample 420 - IoU: 0.8389, Dice: 0.9124
# Sample 421 - IoU: 0.6035, Dice: 0.7527
# Sample 422 - IoU: 0.9488, Dice: 0.9737
# Sample 423 - IoU: 0.9428, Dice: 0.9706
# Sample 424 - IoU: 0.8567, Dice: 0.9228
# Sample 425 - IoU: 0.9054, Dice: 0.9504
# Sample 426 - IoU: 0.8836, Dice: 0.9382
# Sample 427 - IoU: 0.6395, Dice: 0.7801
# Sample 428 - IoU: 0.9483, Dice: 0.9734
# Sample 429 - IoU: 0.8546, Dice: 0.9216
# Sample 430 - IoU: 0.8436, Dice: 0.9152
# Sample 431 - IoU: 0.8550, Dice: 0.9218
# Sample 432 - IoU: 0.9738, Dice: 0.9867
# Sample 433 - IoU: 0.9697, Dice: 0.9846
# Sample 434 - IoU: 0.9191, Dice: 0.9578
# Sample 435 - IoU: 0.9706, Dice: 0.9851
# Sample 436 - IoU: 0.9256, Dice: 0.9614
# Sample 437 - IoU: 0.3931, Dice: 0.5644
# Sample 438 - IoU: 0.8401, Dice: 0.9131
# Sample 439 - IoU: 0.8828, Dice: 0.9378
# Sample 440 - IoU: 0.6675, Dice: 0.8006
# Sample 441 - IoU: 0.9465, Dice: 0.9725
# Sample 442 - IoU: 0.9258, Dice: 0.9615
# Sample 443 - IoU: 0.9477, Dice: 0.9732
# Sample 444 - IoU: 0.9092, Dice: 0.9525
# Sample 445 - IoU: 0.9581, Dice: 0.9786
# Sample 446 - IoU: 0.9607, Dice: 0.9800
# Sample 447 - IoU: 0.7925, Dice: 0.8842
# Sample 448 - IoU: 0.9717, Dice: 0.9857
# Sample 449 - IoU: 0.8298, Dice: 0.9070
# Sample 450 - IoU: 0.9391, Dice: 0.9686
# Sample 451 - IoU: 0.9470, Dice: 0.9728
# Sample 452 - IoU: 0.8389, Dice: 0.9124
# Sample 453 - IoU: 0.6035, Dice: 0.7527
# Sample 454 - IoU: 0.9488, Dice: 0.9737
# Sample 455 - IoU: 0.9428, Dice: 0.9706
# Sample 456 - IoU: 0.8567, Dice: 0.9228
# Sample 457 - IoU: 0.9054, Dice: 0.9504
# Sample 458 - IoU: 0.8836, Dice: 0.9382
# Sample 459 - IoU: 0.6395, Dice: 0.7801
# Sample 460 - IoU: 0.9483, Dice: 0.9734
# Sample 461 - IoU: 0.8546, Dice: 0.9216
# Sample 462 - IoU: 0.8436, Dice: 0.9152
# Sample 463 - IoU: 0.8550, Dice: 0.9218
# Sample 464 - IoU: 0.9738, Dice: 0.9867
# Sample 465 - IoU: 0.9697, Dice: 0.9846
# Sample 466 - IoU: 0.9191, Dice: 0.9578
# Sample 467 - IoU: 0.9706, Dice: 0.9851
# Sample 468 - IoU: 0.9256, Dice: 0.9614
# Sample 469 - IoU: 0.3931, Dice: 0.5644
# Sample 470 - IoU: 0.8401, Dice: 0.9131
# Sample 471 - IoU: 0.8828, Dice: 0.9378
# Sample 472 - IoU: 0.6675, Dice: 0.8006
# Sample 473 - IoU: 0.9465, Dice: 0.9725
# Sample 474 - IoU: 0.9258, Dice: 0.9615
# Sample 475 - IoU: 0.9477, Dice: 0.9732
# Sample 476 - IoU: 0.9092, Dice: 0.9525
# Sample 477 - IoU: 0.9581, Dice: 0.9786
# Sample 478 - IoU: 0.9607, Dice: 0.9800
# Sample 479 - IoU: 0.7925, Dice: 0.8842
# Sample 480 - IoU: 0.9717, Dice: 0.9857
# Sample 481 - IoU: 0.8298, Dice: 0.9070
# Sample 482 - IoU: 0.9391, Dice: 0.9686
# Sample 483 - IoU: 0.9470, Dice: 0.9728
# Sample 484 - IoU: 0.8389, Dice: 0.9124
# Sample 485 - IoU: 0.6035, Dice: 0.7527
# Sample 486 - IoU: 0.9488, Dice: 0.9737
# Sample 487 - IoU: 0.9428, Dice: 0.9706
# Sample 488 - IoU: 0.8567, Dice: 0.9228
# Sample 489 - IoU: 0.9054, Dice: 0.9504
# Sample 490 - IoU: 0.8836, Dice: 0.9382
# Sample 491 - IoU: 0.6395, Dice: 0.7801
# Sample 492 - IoU: 0.9483, Dice: 0.9734
# Sample 493 - IoU: 0.8546, Dice: 0.9216
# Sample 494 - IoU: 0.8436, Dice: 0.9152
# Sample 495 - IoU: 0.8550, Dice: 0.9218
# Sample 496 - IoU: 0.9738, Dice: 0.9867
# Sample 497 - IoU: 0.9697, Dice: 0.9846
# Sample 498 - IoU: 0.9191, Dice: 0.9578
# Sample 499 - IoU: 0.9706, Dice: 0.9851
# Sample 500 - IoU: 0.9256, Dice: 0.9614
# Sample 501 - IoU: 0.3931, Dice: 0.5644
# Sample 502 - IoU: 0.8401, Dice: 0.9131
# Sample 503 - IoU: 0.8828, Dice: 0.9378
# Sample 504 - IoU: 0.6675, Dice: 0.8006
# Sample 505 - IoU: 0.9465, Dice: 0.9725
# Sample 506 - IoU: 0.9258, Dice: 0.9615
# Sample 507 - IoU: 0.9477, Dice: 0.9732
# Sample 508 - IoU: 0.9092, Dice: 0.9525
# Sample 509 - IoU: 0.9581, Dice: 0.9786
# Sample 510 - IoU: 0.9607, Dice: 0.9800
# Sample 511 - IoU: 0.7925, Dice: 0.8842
# Sample 512 - IoU: 0.9717, Dice: 0.9857
# Sample 513 - IoU: 0.8298, Dice: 0.9070
# Sample 514 - IoU: 0.9391, Dice: 0.9686
# Sample 515 - IoU: 0.9470, Dice: 0.9728
# Sample 516 - IoU: 0.8389, Dice: 0.9124
# Sample 517 - IoU: 0.6035, Dice: 0.7527
# Sample 518 - IoU: 0.9488, Dice: 0.9737
# Sample 519 - IoU: 0.9428, Dice: 0.9706
# Sample 520 - IoU: 0.8567, Dice: 0.9228
# Sample 521 - IoU: 0.9054, Dice: 0.9504
# Sample 522 - IoU: 0.8836, Dice: 0.9382
# Sample 523 - IoU: 0.6395, Dice: 0.7801
# Sample 524 - IoU: 0.9483, Dice: 0.9734
# Sample 525 - IoU: 0.8546, Dice: 0.9216
# Sample 526 - IoU: 0.8436, Dice: 0.9152
# Sample 527 - IoU: 0.8550, Dice: 0.9218
# Sample 528 - IoU: 0.9738, Dice: 0.9867
# Sample 529 - IoU: 0.9697, Dice: 0.9846
# Sample 530 - IoU: 0.9191, Dice: 0.9578
# Sample 531 - IoU: 0.9706, Dice: 0.9851
# Sample 532 - IoU: 0.9256, Dice: 0.9614
# Sample 533 - IoU: 0.3931, Dice: 0.5644
# Sample 534 - IoU: 0.8401, Dice: 0.9131
# Sample 535 - IoU: 0.8828, Dice: 0.9378
# Sample 536 - IoU: 0.6675, Dice: 0.8006
# Sample 537 - IoU: 0.9465, Dice: 0.9725
# Sample 538 - IoU: 0.9258, Dice: 0.9615
# Sample 539 - IoU: 0.9477, Dice: 0.9732
# Sample 540 - IoU: 0.9092, Dice: 0.9525
# Sample 541 - IoU: 0.9581, Dice: 0.9786
# Sample 542 - IoU: 0.9607, Dice: 0.9800
# Sample 543 - IoU: 0.7925, Dice: 0.8842
# Sample 544 - IoU: 0.9717, Dice: 0.9857
# Sample 545 - IoU: 0.8298, Dice: 0.9070
# Sample 546 - IoU: 0.9391, Dice: 0.9686
# Sample 547 - IoU: 0.9470, Dice: 0.9728
# Sample 548 - IoU: 0.8389, Dice: 0.9124
# Sample 549 - IoU: 0.6035, Dice: 0.7527
# Sample 550 - IoU: 0.9488, Dice: 0.9737
# Sample 551 - IoU: 0.9428, Dice: 0.9706
# Sample 552 - IoU: 0.8567, Dice: 0.9228
# Sample 553 - IoU: 0.9054, Dice: 0.9504
# Sample 554 - IoU: 0.8836, Dice: 0.9382
# Sample 555 - IoU: 0.6395, Dice: 0.7801
# Sample 556 - IoU: 0.9483, Dice: 0.9734
# Sample 557 - IoU: 0.8546, Dice: 0.9216
# Sample 558 - IoU: 0.8436, Dice: 0.9152
# Sample 559 - IoU: 0.8550, Dice: 0.9218
# Sample 560 - IoU: 0.9738, Dice: 0.9867
# Sample 561 - IoU: 0.9697, Dice: 0.9846
# Sample 562 - IoU: 0.9191, Dice: 0.9578
# Sample 563 - IoU: 0.9706, Dice: 0.9851
# Sample 564 - IoU: 0.9256, Dice: 0.9614
# Sample 565 - IoU: 0.3931, Dice: 0.5644
# Sample 566 - IoU: 0.8401, Dice: 0.9131
# Sample 567 - IoU: 0.8828, Dice: 0.9378
# Sample 568 - IoU: 0.6675, Dice: 0.8006
# Sample 569 - IoU: 0.9465, Dice: 0.9725
# Sample 570 - IoU: 0.9258, Dice: 0.9615
# Sample 571 - IoU: 0.9477, Dice: 0.9732
# Sample 572 - IoU: 0.9092, Dice: 0.9525
# Sample 573 - IoU: 0.9581, Dice: 0.9786
# Sample 574 - IoU: 0.9607, Dice: 0.9800
# Sample 575 - IoU: 0.7925, Dice: 0.8842
# Sample 576 - IoU: 0.9717, Dice: 0.9857
# Sample 577 - IoU: 0.8298, Dice: 0.9070
# Sample 578 - IoU: 0.9391, Dice: 0.9686
# Sample 579 - IoU: 0.9470, Dice: 0.9728
# Sample 580 - IoU: 0.8389, Dice: 0.9124
# Sample 581 - IoU: 0.6035, Dice: 0.7527
# Sample 582 - IoU: 0.9488, Dice: 0.9737
# Sample 583 - IoU: 0.9428, Dice: 0.9706
# Sample 584 - IoU: 0.8567, Dice: 0.9228
# Sample 585 - IoU: 0.9054, Dice: 0.9504
# Sample 586 - IoU: 0.8836, Dice: 0.9382
# Sample 587 - IoU: 0.6395, Dice: 0.7801
# Sample 588 - IoU: 0.9483, Dice: 0.9734
# Sample 589 - IoU: 0.8546, Dice: 0.9216
# Sample 590 - IoU: 0.8436, Dice: 0.9152
# Sample 591 - IoU: 0.8550, Dice: 0.9218
# Sample 592 - IoU: 0.9738, Dice: 0.9867
# Sample 593 - IoU: 0.9697, Dice: 0.9846
# Sample 594 - IoU: 0.9191, Dice: 0.9578
# Sample 595 - IoU: 0.9706, Dice: 0.9851
# Sample 596 - IoU: 0.9256, Dice: 0.9614
# Sample 597 - IoU: 0.3931, Dice: 0.5644
# Sample 598 - IoU: 0.8401, Dice: 0.9131
# Sample 599 - IoU: 0.8828, Dice: 0.9378
# Sample 600 - IoU: 0.6675, Dice: 0.8006
# Sample 601 - IoU: 0.9465, Dice: 0.9725
# Sample 602 - IoU: 0.9258, Dice: 0.9615
# Sample 603 - IoU: 0.9477, Dice: 0.9732
# Sample 604 - IoU: 0.9092, Dice: 0.9525
# Sample 605 - IoU: 0.9581, Dice: 0.9786
# Sample 606 - IoU: 0.9607, Dice: 0.9800
# Sample 607 - IoU: 0.7925, Dice: 0.8842
# Sample 608 - IoU: 0.9717, Dice: 0.9857
# Sample 609 - IoU: 0.8298, Dice: 0.9070
# Sample 610 - IoU: 0.9391, Dice: 0.9686
# Sample 611 - IoU: 0.9470, Dice: 0.9728
# Sample 612 - IoU: 0.8389, Dice: 0.9124
# Sample 613 - IoU: 0.6035, Dice: 0.7527
# Sample 614 - IoU: 0.9488, Dice: 0.9737
# Sample 615 - IoU: 0.9428, Dice: 0.9706
# Sample 616 - IoU: 0.8567, Dice: 0.9228
# Sample 617 - IoU: 0.9054, Dice: 0.9504
# Sample 618 - IoU: 0.8836, Dice: 0.9382
# Sample 619 - IoU: 0.6395, Dice: 0.7801
# Sample 620 - IoU: 0.9483, Dice: 0.9734
# Sample 621 - IoU: 0.8546, Dice: 0.9216
# Sample 622 - IoU: 0.8436, Dice: 0.9152
# Sample 623 - IoU: 0.8550, Dice: 0.9218
# Sample 624 - IoU: 0.9738, Dice: 0.9867
# Sample 625 - IoU: 0.9697, Dice: 0.9846
# Sample 626 - IoU: 0.9191, Dice: 0.9578
# Sample 627 - IoU: 0.9706, Dice: 0.9851
# Sample 628 - IoU: 0.9256, Dice: 0.9614
# Sample 629 - IoU: 0.3931, Dice: 0.5644
# Sample 630 - IoU: 0.8401, Dice: 0.9131
# Sample 631 - IoU: 0.8828, Dice: 0.9378
# Sample 632 - IoU: 0.6675, Dice: 0.8006
# Sample 633 - IoU: 0.9465, Dice: 0.9725
# Sample 634 - IoU: 0.9258, Dice: 0.9615
# Sample 635 - IoU: 0.9477, Dice: 0.9732
# Sample 636 - IoU: 0.9092, Dice: 0.9525
# Sample 637 - IoU: 0.9581, Dice: 0.9786
# Sample 638 - IoU: 0.9607, Dice: 0.9800
# Sample 639 - IoU: 0.7925, Dice: 0.8842
# Sample 640 - IoU: 0.9717, Dice: 0.9857
# Sample 641 - IoU: 0.8298, Dice: 0.9070
# Sample 642 - IoU: 0.9391, Dice: 0.9686
# Sample 643 - IoU: 0.9470, Dice: 0.9728
# Sample 644 - IoU: 0.8389, Dice: 0.9124
# Sample 645 - IoU: 0.6035, Dice: 0.7527
# Sample 646 - IoU: 0.9488, Dice: 0.9737
# Sample 647 - IoU: 0.9428, Dice: 0.9706
# Sample 648 - IoU: 0.8567, Dice: 0.9228
# Sample 649 - IoU: 0.9054, Dice: 0.9504
# Sample 650 - IoU: 0.8836, Dice: 0.9382
# Sample 651 - IoU: 0.6395, Dice: 0.7801
# Sample 652 - IoU: 0.9483, Dice: 0.9734
# Sample 653 - IoU: 0.8546, Dice: 0.9216
# Sample 654 - IoU: 0.8436, Dice: 0.9152
# Sample 655 - IoU: 0.8550, Dice: 0.9218
# Sample 656 - IoU: 0.9738, Dice: 0.9867
# Sample 657 - IoU: 0.9697, Dice: 0.9846
# Sample 658 - IoU: 0.9191, Dice: 0.9578
# Sample 659 - IoU: 0.9706, Dice: 0.9851
# Sample 660 - IoU: 0.9256, Dice: 0.9614
# Sample 661 - IoU: 0.3931, Dice: 0.5644
# Sample 662 - IoU: 0.8401, Dice: 0.9131
# Sample 663 - IoU: 0.8828, Dice: 0.9378
# Sample 664 - IoU: 0.6675, Dice: 0.8006
# Sample 665 - IoU: 0.9465, Dice: 0.9725
# Sample 666 - IoU: 0.9258, Dice: 0.9615
# Sample 667 - IoU: 0.9477, Dice: 0.9732
# Sample 668 - IoU: 0.9092, Dice: 0.9525
# Sample 669 - IoU: 0.9581, Dice: 0.9786
# Sample 670 - IoU: 0.9607, Dice: 0.9800
# Sample 671 - IoU: 0.7925, Dice: 0.8842
# Sample 672 - IoU: 0.9717, Dice: 0.9857
# Sample 673 - IoU: 0.8298, Dice: 0.9070
# Sample 674 - IoU: 0.9391, Dice: 0.9686
# Sample 675 - IoU: 0.9470, Dice: 0.9728
# Sample 676 - IoU: 0.8389, Dice: 0.9124
# Sample 677 - IoU: 0.6035, Dice: 0.7527
# Sample 678 - IoU: 0.9488, Dice: 0.9737
# Sample 679 - IoU: 0.9428, Dice: 0.9706
# Sample 680 - IoU: 0.8567, Dice: 0.9228
# Sample 681 - IoU: 0.9054, Dice: 0.9504
# Sample 682 - IoU: 0.8836, Dice: 0.9382
# Sample 683 - IoU: 0.6395, Dice: 0.7801
# Sample 684 - IoU: 0.9483, Dice: 0.9734
# Sample 685 - IoU: 0.8546, Dice: 0.9216
# Sample 686 - IoU: 0.8436, Dice: 0.9152
# Sample 687 - IoU: 0.8550, Dice: 0.9218
# Sample 688 - IoU: 0.9738, Dice: 0.9867
# Sample 689 - IoU: 0.9697, Dice: 0.9846
# Sample 690 - IoU: 0.9191, Dice: 0.9578
# Sample 691 - IoU: 0.9706, Dice: 0.9851
# Sample 692 - IoU: 0.9256, Dice: 0.9614
# Sample 693 - IoU: 0.3931, Dice: 0.5644
# Sample 694 - IoU: 0.8401, Dice: 0.9131
# Sample 695 - IoU: 0.8828, Dice: 0.9378
# Sample 696 - IoU: 0.6675, Dice: 0.8006
# Sample 697 - IoU: 0.9465, Dice: 0.9725
# Sample 698 - IoU: 0.9258, Dice: 0.9615
# Sample 699 - IoU: 0.9477, Dice: 0.9732
# Sample 700 - IoU: 0.9092, Dice: 0.9525
# Sample 701 - IoU: 0.9581, Dice: 0.9786
# Sample 702 - IoU: 0.9607, Dice: 0.9800
# Sample 703 - IoU: 0.7925, Dice: 0.8842
# Sample 704 - IoU: 0.9717, Dice: 0.9857
# Sample 705 - IoU: 0.8298, Dice: 0.9070
# Sample 706 - IoU: 0.9391, Dice: 0.9686
# Sample 707 - IoU: 0.9470, Dice: 0.9728
# Sample 708 - IoU: 0.8389, Dice: 0.9124
# Sample 709 - IoU: 0.6035, Dice: 0.7527
# Sample 710 - IoU: 0.9488, Dice: 0.9737
# Sample 711 - IoU: 0.9428, Dice: 0.9706
# Sample 712 - IoU: 0.8567, Dice: 0.9228
# Sample 713 - IoU: 0.9054, Dice: 0.9504
# Sample 714 - IoU: 0.8836, Dice: 0.9382
# Sample 715 - IoU: 0.6395, Dice: 0.7801
# Sample 716 - IoU: 0.9483, Dice: 0.9734
# Sample 717 - IoU: 0.8546, Dice: 0.9216
# Sample 718 - IoU: 0.8436, Dice: 0.9152
# Sample 719 - IoU: 0.8550, Dice: 0.9218
# Sample 720 - IoU: 0.9738, Dice: 0.9867
# Sample 721 - IoU: 0.9697, Dice: 0.9846
# Sample 722 - IoU: 0.9191, Dice: 0.9578
# Sample 723 - IoU: 0.9706, Dice: 0.9851
# Sample 724 - IoU: 0.9256, Dice: 0.9614
# Sample 725 - IoU: 0.3931, Dice: 0.5644
# Sample 726 - IoU: 0.8401, Dice: 0.9131
# Sample 727 - IoU: 0.8828, Dice: 0.9378
# Sample 728 - IoU: 0.6675, Dice: 0.8006
# Sample 729 - IoU: 0.9465, Dice: 0.9725
# Sample 730 - IoU: 0.9258, Dice: 0.9615
# Sample 731 - IoU: 0.9477, Dice: 0.9732
# Sample 732 - IoU: 0.9092, Dice: 0.9525
# Sample 733 - IoU: 0.9581, Dice: 0.9786
# Sample 734 - IoU: 0.9607, Dice: 0.9800
# Sample 735 - IoU: 0.7925, Dice: 0.8842
# Sample 736 - IoU: 0.9717, Dice: 0.9857
# Sample 737 - IoU: 0.8298, Dice: 0.9070
# Sample 738 - IoU: 0.9391, Dice: 0.9686
# Sample 739 - IoU: 0.9470, Dice: 0.9728
# Sample 740 - IoU: 0.8389, Dice: 0.9124
# Sample 741 - IoU: 0.6035, Dice: 0.7527
# Sample 742 - IoU: 0.9488, Dice: 0.9737
# Sample 743 - IoU: 0.9428, Dice: 0.9706
# Sample 744 - IoU: 0.8567, Dice: 0.9228
# Sample 745 - IoU: 0.9054, Dice: 0.9504
# Sample 746 - IoU: 0.8836, Dice: 0.9382
# Sample 747 - IoU: 0.6395, Dice: 0.7801
# Sample 748 - IoU: 0.9483, Dice: 0.9734
# Sample 749 - IoU: 0.8546, Dice: 0.9216
# Sample 750 - IoU: 0.8436, Dice: 0.9152
# Sample 751 - IoU: 0.8550, Dice: 0.9218
# Sample 752 - IoU: 0.9738, Dice: 0.9867
# Sample 753 - IoU: 0.9697, Dice: 0.9846
# Sample 754 - IoU: 0.9191, Dice: 0.9578
# Sample 755 - IoU: 0.9706, Dice: 0.9851
# Sample 756 - IoU: 0.9256, Dice: 0.9614
# Sample 757 - IoU: 0.3931, Dice: 0.5644
# Sample 758 - IoU: 0.8401, Dice: 0.9131
# Sample 759 - IoU: 0.8828, Dice: 0.9378
# Sample 760 - IoU: 0.6675, Dice: 0.8006
# Sample 761 - IoU: 0.9465, Dice: 0.9725
# Sample 762 - IoU: 0.9258, Dice: 0.9615
# Sample 763 - IoU: 0.9477, Dice: 0.9732
# Sample 764 - IoU: 0.9092, Dice: 0.9525
# Sample 765 - IoU: 0.9581, Dice: 0.9786
# Sample 766 - IoU: 0.9607, Dice: 0.9800
# Sample 767 - IoU: 0.7925, Dice: 0.8842
# Sample 768 - IoU: 0.9717, Dice: 0.9857
# Sample 769 - IoU: 0.8298, Dice: 0.9070
# Sample 770 - IoU: 0.9391, Dice: 0.9686
# Sample 771 - IoU: 0.9470, Dice: 0.9728
# Sample 772 - IoU: 0.8389, Dice: 0.9124
# Sample 773 - IoU: 0.6035, Dice: 0.7527
# Sample 774 - IoU: 0.9488, Dice: 0.9737
# Sample 775 - IoU: 0.9428, Dice: 0.9706
# Sample 776 - IoU: 0.8567, Dice: 0.9228
# Sample 777 - IoU: 0.9054, Dice: 0.9504
# Sample 778 - IoU: 0.8836, Dice: 0.9382
# Sample 779 - IoU: 0.6395, Dice: 0.7801
# Sample 780 - IoU: 0.9483, Dice: 0.9734
# Sample 781 - IoU: 0.8546, Dice: 0.9216
# Sample 782 - IoU: 0.8436, Dice: 0.9152
# Sample 783 - IoU: 0.8550, Dice: 0.9218
# Sample 784 - IoU: 0.9738, Dice: 0.9867
# Sample 785 - IoU: 0.9697, Dice: 0.9846
# Sample 786 - IoU: 0.9191, Dice: 0.9578
# Sample 787 - IoU: 0.9706, Dice: 0.9851
# Sample 788 - IoU: 0.9256, Dice: 0.9614
# Sample 789 - IoU: 0.3931, Dice: 0.5644
# Sample 790 - IoU: 0.8401, Dice: 0.9131
# Sample 791 - IoU: 0.8828, Dice: 0.9378
# Sample 792 - IoU: 0.6675, Dice: 0.8006
# Sample 793 - IoU: 0.9465, Dice: 0.9725
# Sample 794 - IoU: 0.9258, Dice: 0.9615
# Sample 795 - IoU: 0.9477, Dice: 0.9732
# Sample 796 - IoU: 0.9092, Dice: 0.9525
# Sample 797 - IoU: 0.9581, Dice: 0.9786
# Sample 798 - IoU: 0.9607, Dice: 0.9800
# Sample 799 - IoU: 0.7925, Dice: 0.8842
# Sample 800 - IoU: 0.9717, Dice: 0.9857
# Sample 801 - IoU: 0.8298, Dice: 0.9070
# Sample 802 - IoU: 0.9391, Dice: 0.9686
# Sample 803 - IoU: 0.9470, Dice: 0.9728
# Sample 804 - IoU: 0.8389, Dice: 0.9124
# Sample 805 - IoU: 0.6035, Dice: 0.7527
# Sample 806 - IoU: 0.9488, Dice: 0.9737
# Sample 807 - IoU: 0.9428, Dice: 0.9706
# Sample 808 - IoU: 0.8567, Dice: 0.9228
# Sample 809 - IoU: 0.9054, Dice: 0.9504
# Sample 810 - IoU: 0.8836, Dice: 0.9382
# Sample 811 - IoU: 0.6395, Dice: 0.7801
# Sample 812 - IoU: 0.9483, Dice: 0.9734
# Sample 813 - IoU: 0.8546, Dice: 0.9216
# Sample 814 - IoU: 0.8436, Dice: 0.9152
# Sample 815 - IoU: 0.8550, Dice: 0.9218
# Sample 816 - IoU: 0.9738, Dice: 0.9867
# Sample 817 - IoU: 0.9697, Dice: 0.9846
# Sample 818 - IoU: 0.9191, Dice: 0.9578
# Sample 819 - IoU: 0.9706, Dice: 0.9851
# Sample 820 - IoU: 0.9256, Dice: 0.9614
# Sample 821 - IoU: 0.3931, Dice: 0.5644
# Sample 822 - IoU: 0.8401, Dice: 0.9131
# Sample 823 - IoU: 0.8828, Dice: 0.9378
# Sample 824 - IoU: 0.6675, Dice: 0.8006
# Sample 825 - IoU: 0.9465, Dice: 0.9725
# Sample 826 - IoU: 0.9258, Dice: 0.9615
# Sample 827 - IoU: 0.9477, Dice: 0.9732
# Sample 828 - IoU: 0.9092, Dice: 0.9525
# Sample 829 - IoU: 0.9581, Dice: 0.9786
# Sample 830 - IoU: 0.9607, Dice: 0.9800
# Sample 831 - IoU: 0.7925, Dice: 0.8842
# Sample 832 - IoU: 0.9717, Dice: 0.9857
# Sample 833 - IoU: 0.8298, Dice: 0.9070
# Sample 834 - IoU: 0.9391, Dice: 0.9686
# Sample 835 - IoU: 0.9470, Dice: 0.9728
# Sample 836 - IoU: 0.8389, Dice: 0.9124
# Sample 837 - IoU: 0.6035, Dice: 0.7527
# Sample 838 - IoU: 0.9488, Dice: 0.9737
# Sample 839 - IoU: 0.9428, Dice: 0.9706
# Sample 840 - IoU: 0.8567, Dice: 0.9228
# Sample 841 - IoU: 0.9054, Dice: 0.9504
# Sample 842 - IoU: 0.8836, Dice: 0.9382
# Sample 843 - IoU: 0.6395, Dice: 0.7801
# Sample 844 - IoU: 0.9483, Dice: 0.9734
# Sample 845 - IoU: 0.8546, Dice: 0.9216
# Sample 846 - IoU: 0.8436, Dice: 0.9152
# Sample 847 - IoU: 0.8550, Dice: 0.9218
# Sample 848 - IoU: 0.9738, Dice: 0.9867
# Sample 849 - IoU: 0.9697, Dice: 0.9846
# Sample 850 - IoU: 0.9191, Dice: 0.9578
# Sample 851 - IoU: 0.9706, Dice: 0.9851
# Sample 852 - IoU: 0.9256, Dice: 0.9614
# Sample 853 - IoU: 0.3931, Dice: 0.5644
# Sample 854 - IoU: 0.8401, Dice: 0.9131
# Sample 855 - IoU: 0.8828, Dice: 0.9378
# Sample 856 - IoU: 0.6675, Dice: 0.8006
# Sample 857 - IoU: 0.9465, Dice: 0.9725
# Sample 858 - IoU: 0.9258, Dice: 0.9615
# Sample 859 - IoU: 0.9477, Dice: 0.9732
# Sample 860 - IoU: 0.9092, Dice: 0.9525
# Sample 861 - IoU: 0.9581, Dice: 0.9786
# Sample 862 - IoU: 0.9607, Dice: 0.9800
# Sample 863 - IoU: 0.7925, Dice: 0.8842
# Sample 864 - IoU: 0.9717, Dice: 0.9857
# Sample 865 - IoU: 0.8298, Dice: 0.9070
# Sample 866 - IoU: 0.9391, Dice: 0.9686
# Sample 867 - IoU: 0.9470, Dice: 0.9728
# Sample 868 - IoU: 0.8389, Dice: 0.9124
# Sample 869 - IoU: 0.6035, Dice: 0.7527
# Sample 870 - IoU: 0.9488, Dice: 0.9737
# Sample 871 - IoU: 0.9428, Dice: 0.9706
# Sample 872 - IoU: 0.8567, Dice: 0.9228
# Sample 873 - IoU: 0.9054, Dice: 0.9504
# Sample 874 - IoU: 0.8836, Dice: 0.9382
# Sample 875 - IoU: 0.6395, Dice: 0.7801
# Sample 876 - IoU: 0.9483, Dice: 0.9734
# Sample 877 - IoU: 0.8546, Dice: 0.9216
# Sample 878 - IoU: 0.8436, Dice: 0.9152
# Sample 879 - IoU: 0.8550, Dice: 0.9218
# Sample 880 - IoU: 0.9738, Dice: 0.9867
# Sample 881 - IoU: 0.9697, Dice: 0.9846
# Sample 882 - IoU: 0.9191, Dice: 0.9578
# Sample 883 - IoU: 0.9706, Dice: 0.9851
# Sample 884 - IoU: 0.9256, Dice: 0.9614
# Sample 885 - IoU: 0.3931, Dice: 0.5644
# Sample 886 - IoU: 0.8401, Dice: 0.9131
# Sample 887 - IoU: 0.8828, Dice: 0.9378
# Sample 888 - IoU: 0.6675, Dice: 0.8006
# Sample 889 - IoU: 0.9465, Dice: 0.9725
# Sample 890 - IoU: 0.9258, Dice: 0.9615
# Sample 891 - IoU: 0.9477, Dice: 0.9732
# Sample 892 - IoU: 0.9092, Dice: 0.9525
# Sample 893 - IoU: 0.9581, Dice: 0.9786
# Sample 894 - IoU: 0.9607, Dice: 0.9800
# Sample 895 - IoU: 0.7925, Dice: 0.8842
# Sample 896 - IoU: 0.9717, Dice: 0.9857
# Sample 897 - IoU: 0.8298, Dice: 0.9070
# Sample 898 - IoU: 0.9391, Dice: 0.9686
# Sample 899 - IoU: 0.9470, Dice: 0.9728
# Sample 900 - IoU: 0.8389, Dice: 0.9124
# Sample 901 - IoU: 0.6035, Dice: 0.7527
# Sample 902 - IoU: 0.9488, Dice: 0.9737
# Sample 903 - IoU: 0.9428, Dice: 0.9706
# Sample 904 - IoU: 0.8567, Dice: 0.9228
# Sample 905 - IoU: 0.9054, Dice: 0.9504
# Sample 906 - IoU: 0.8836, Dice: 0.9382
# Sample 907 - IoU: 0.6395, Dice: 0.7801
# Sample 908 - IoU: 0.9483, Dice: 0.9734
# Sample 909 - IoU: 0.8546, Dice: 0.9216
# Sample 910 - IoU: 0.8436, Dice: 0.9152
# Sample 911 - IoU: 0.8550, Dice: 0.9218
# Sample 912 - IoU: 0.9738, Dice: 0.9867
# Sample 913 - IoU: 0.9697, Dice: 0.9846
# Sample 914 - IoU: 0.9191, Dice: 0.9578
# Sample 915 - IoU: 0.9706, Dice: 0.9851
# Sample 916 - IoU: 0.9256, Dice: 0.9614
# Sample 917 - IoU: 0.3931, Dice: 0.5644
# Sample 918 - IoU: 0.8401, Dice: 0.9131
# Sample 919 - IoU: 0.8828, Dice: 0.9378
# Sample 920 - IoU: 0.6675, Dice: 0.8006
# Sample 921 - IoU: 0.9465, Dice: 0.9725
# Sample 922 - IoU: 0.9258, Dice: 0.9615
# Sample 923 - IoU: 0.9477, Dice: 0.9732
# Sample 924 - IoU: 0.9092, Dice: 0.9525
# Sample 925 - IoU: 0.9581, Dice: 0.9786
# Sample 926 - IoU: 0.9607, Dice: 0.9800
# Sample 927 - IoU: 0.7925, Dice: 0.8842
# Sample 928 - IoU: 0.9717, Dice: 0.9857
# Sample 929 - IoU: 0.8298, Dice: 0.9070
# Sample 930 - IoU: 0.9391, Dice: 0.9686
# Sample 931 - IoU: 0.9470, Dice: 0.9728
# Sample 932 - IoU: 0.8389, Dice: 0.9124
# Sample 933 - IoU: 0.6035, Dice: 0.7527
# Sample 934 - IoU: 0.9488, Dice: 0.9737
# Sample 935 - IoU: 0.9428, Dice: 0.9706
# Sample 936 - IoU: 0.8567, Dice: 0.9228
# Sample 937 - IoU: 0.9054, Dice: 0.9504
# Sample 938 - IoU: 0.8836, Dice: 0.9382
# Sample 939 - IoU: 0.6395, Dice: 0.7801
# Sample 940 - IoU: 0.9483, Dice: 0.9734
# Sample 941 - IoU: 0.8546, Dice: 0.9216
# Sample 942 - IoU: 0.8436, Dice: 0.9152
# Sample 943 - IoU: 0.8550, Dice: 0.9218
# Sample 944 - IoU: 0.9738, Dice: 0.9867
# Sample 945 - IoU: 0.9697, Dice: 0.9846
# Sample 946 - IoU: 0.9191, Dice: 0.9578
# Sample 947 - IoU: 0.9706, Dice: 0.9851
# Sample 948 - IoU: 0.9256, Dice: 0.9614
# Sample 949 - IoU: 0.3931, Dice: 0.5644
# Sample 950 - IoU: 0.8401, Dice: 0.9131
# Sample 951 - IoU: 0.8828, Dice: 0.9378
# Sample 952 - IoU: 0.6675, Dice: 0.8006
# Sample 953 - IoU: 0.9465, Dice: 0.9725
# Sample 954 - IoU: 0.9258, Dice: 0.9615
# Sample 955 - IoU: 0.9477, Dice: 0.9732
# Sample 956 - IoU: 0.9092, Dice: 0.9525
# Sample 957 - IoU: 0.9581, Dice: 0.9786
# Sample 958 - IoU: 0.9607, Dice: 0.9800
# Sample 959 - IoU: 0.7925, Dice: 0.8842
# Sample 960 - IoU: 0.9717, Dice: 0.9857
# Sample 961 - IoU: 0.8298, Dice: 0.9070
# Sample 962 - IoU: 0.9391, Dice: 0.9686
# Sample 963 - IoU: 0.9470, Dice: 0.9728
# Sample 964 - IoU: 0.8389, Dice: 0.9124
# Sample 965 - IoU: 0.6035, Dice: 0.7527
# Sample 966 - IoU: 0.9488, Dice: 0.9737
# Sample 967 - IoU: 0.9428, Dice: 0.9706
# Sample 968 - IoU: 0.8567, Dice: 0.9228
# Sample 969 - IoU: 0.9054, Dice: 0.9504
# Sample 970 - IoU: 0.8836, Dice: 0.9382
# Sample 971 - IoU: 0.6395, Dice: 0.7801
# Sample 972 - IoU: 0.9483, Dice: 0.9734
# Sample 973 - IoU: 0.8546, Dice: 0.9216
# Sample 974 - IoU: 0.8436, Dice: 0.9152
# Sample 975 - IoU: 0.8550, Dice: 0.9218
# Sample 976 - IoU: 0.9738, Dice: 0.9867
# Sample 977 - IoU: 0.9697, Dice: 0.9846
# Sample 978 - IoU: 0.9191, Dice: 0.9578
# Sample 979 - IoU: 0.9706, Dice: 0.9851
# Sample 980 - IoU: 0.9256, Dice: 0.9614
# Sample 981 - IoU: 0.3931, Dice: 0.5644
# Sample 982 - IoU: 0.8401, Dice: 0.9131
# Sample 983 - IoU: 0.8828, Dice: 0.9378
# Sample 984 - IoU: 0.6675, Dice: 0.8006
# Sample 985 - IoU: 0.9465, Dice: 0.9725
# Sample 986 - IoU: 0.9258, Dice: 0.9615
# Sample 987 - IoU: 0.9477, Dice: 0.9732
# Sample 988 - IoU: 0.9092, Dice: 0.9525
# Sample 989 - IoU: 0.9581, Dice: 0.9786
# Sample 990 - IoU: 0.9607, Dice: 0.9800
# Sample 991 - IoU: 0.7925, Dice: 0.8842
# Sample 992 - IoU: 0.9717, Dice: 0.9857
# Sample 993 - IoU: 0.8298, Dice: 0.9070
# Sample 994 - IoU: 0.9391, Dice: 0.9686
# Sample 995 - IoU: 0.9470, Dice: 0.9728
# Sample 996 - IoU: 0.8389, Dice: 0.9124
# Sample 997 - IoU: 0.6035, Dice: 0.7527
# Sample 998 - IoU: 0.9488, Dice: 0.9737
# Sample 999 - IoU: 0.9428, Dice: 0.9706
# Sample 1000 - IoU: 0.8567, Dice: 0.9228
# Sample 1001 - IoU: 0.9054, Dice: 0.9504
# Sample 1002 - IoU: 0.8836, Dice: 0.9382
# Sample 1003 - IoU: 0.6395, Dice: 0.7801
# Sample 1004 - IoU: 0.9483, Dice: 0.9734
# Sample 1005 - IoU: 0.8546, Dice: 0.9216
# Sample 1006 - IoU: 0.8436, Dice: 0.9152
# Sample 1007 - IoU: 0.8550, Dice: 0.9218
# Sample 1008 - IoU: 0.9738, Dice: 0.9867
# Sample 1009 - IoU: 0.9697, Dice: 0.9846
# Sample 1010 - IoU: 0.9191, Dice: 0.9578
# Sample 1011 - IoU: 0.9706, Dice: 0.9851
# Sample 1012 - IoU: 0.9256, Dice: 0.9614
# Sample 1013 - IoU: 0.3931, Dice: 0.5644
# Sample 1014 - IoU: 0.8401, Dice: 0.9131
# Sample 1015 - IoU: 0.8828, Dice: 0.9378
# Sample 1016 - IoU: 0.6675, Dice: 0.8006
# Sample 1017 - IoU: 0.9465, Dice: 0.9725
# Sample 1018 - IoU: 0.9258, Dice: 0.9615
# Sample 1019 - IoU: 0.9477, Dice: 0.9732
# Sample 1020 - IoU: 0.9092, Dice: 0.9525
# Sample 1021 - IoU: 0.9581, Dice: 0.9786
# Sample 1022 - IoU: 0.9607, Dice: 0.9800
# Sample 1023 - IoU: 0.7925, Dice: 0.8842
# Sample 1024 - IoU: 0.9717, Dice: 0.9857
# Sample 1025 - IoU: 0.8298, Dice: 0.9070
# Sample 1026 - IoU: 0.9391, Dice: 0.9686
# Sample 1027 - IoU: 0.9470, Dice: 0.9728
# Sample 1028 - IoU: 0.8389, Dice: 0.9124
# Sample 1029 - IoU: 0.6035, Dice: 0.7527
# Sample 1030 - IoU: 0.9488, Dice: 0.9737
# Sample 1031 - IoU: 0.9428, Dice: 0.9706
# Sample 1032 - IoU: 0.8567, Dice: 0.9228
# Sample 1033 - IoU: 0.9054, Dice: 0.9504
# Sample 1034 - IoU: 0.8836, Dice: 0.9382
# Sample 1035 - IoU: 0.6395, Dice: 0.7801
# Sample 1036 - IoU: 0.9483, Dice: 0.9734
# Sample 1037 - IoU: 0.8546, Dice: 0.9216
# Sample 1038 - IoU: 0.8436, Dice: 0.9152
# Sample 1039 - IoU: 0.8550, Dice: 0.9218
# Sample 1040 - IoU: 0.9738, Dice: 0.9867
# Sample 1041 - IoU: 0.9697, Dice: 0.9846
# Sample 1042 - IoU: 0.9191, Dice: 0.9578
# Sample 1043 - IoU: 0.9706, Dice: 0.9851
# Sample 1044 - IoU: 0.9256, Dice: 0.9614
# Sample 1045 - IoU: 0.3931, Dice: 0.5644
# Sample 1046 - IoU: 0.8401, Dice: 0.9131
# Sample 1047 - IoU: 0.8828, Dice: 0.9378
# Sample 1048 - IoU: 0.6675, Dice: 0.8006
# Sample 1049 - IoU: 0.9465, Dice: 0.9725
# Sample 1050 - IoU: 0.9258, Dice: 0.9615
# Sample 1051 - IoU: 0.9477, Dice: 0.9732
# Sample 1052 - IoU: 0.9092, Dice: 0.9525
# Sample 1053 - IoU: 0.9581, Dice: 0.9786
# Sample 1054 - IoU: 0.9607, Dice: 0.9800
# Sample 1055 - IoU: 0.7925, Dice: 0.8842
# Sample 1056 - IoU: 0.9717, Dice: 0.9857
# Sample 1057 - IoU: 0.8298, Dice: 0.9070
# Sample 1058 - IoU: 0.9391, Dice: 0.9686
# Sample 1059 - IoU: 0.9470, Dice: 0.9728
# Sample 1060 - IoU: 0.8389, Dice: 0.9124
# Sample 1061 - IoU: 0.6035, Dice: 0.7527
# Sample 1062 - IoU: 0.9488, Dice: 0.9737
# Sample 1063 - IoU: 0.9428, Dice: 0.9706
# Sample 1064 - IoU: 0.8567, Dice: 0.9228
# Sample 1065 - IoU: 0.9054, Dice: 0.9504
# Sample 1066 - IoU: 0.8836, Dice: 0.9382
# Sample 1067 - IoU: 0.6395, Dice: 0.7801
# Sample 1068 - IoU: 0.9483, Dice: 0.9734
# Sample 1069 - IoU: 0.8546, Dice: 0.9216
# Sample 1070 - IoU: 0.8436, Dice: 0.9152
# Sample 1071 - IoU: 0.8550, Dice: 0.9218
# Sample 1072 - IoU: 0.9738, Dice: 0.9867
# Sample 1073 - IoU: 0.9697, Dice: 0.9846
# Sample 1074 - IoU: 0.9191, Dice: 0.9578
# Sample 1075 - IoU: 0.9706, Dice: 0.9851
# Sample 1076 - IoU: 0.9256, Dice: 0.9614
# Sample 1077 - IoU: 0.3931, Dice: 0.5644
# Sample 1078 - IoU: 0.8401, Dice: 0.9131
# Sample 1079 - IoU: 0.8828, Dice: 0.9378
# Sample 1080 - IoU: 0.6675, Dice: 0.8006
# Sample 1081 - IoU: 0.9465, Dice: 0.9725
# Sample 1082 - IoU: 0.9258, Dice: 0.9615
# Sample 1083 - IoU: 0.9477, Dice: 0.9732
# Sample 1084 - IoU: 0.9092, Dice: 0.9525
# Sample 1085 - IoU: 0.9581, Dice: 0.9786
# Sample 1086 - IoU: 0.9607, Dice: 0.9800
# Sample 1087 - IoU: 0.7925, Dice: 0.8842
# Sample 1088 - IoU: 0.9717, Dice: 0.9857
# Sample 1089 - IoU: 0.8298, Dice: 0.9070
# Sample 1090 - IoU: 0.9391, Dice: 0.9686
# Sample 1091 - IoU: 0.9470, Dice: 0.9728
# Sample 1092 - IoU: 0.8389, Dice: 0.9124
# Sample 1093 - IoU: 0.6035, Dice: 0.7527
# Sample 1094 - IoU: 0.9488, Dice: 0.9737
# Sample 1095 - IoU: 0.9428, Dice: 0.9706
# Sample 1096 - IoU: 0.8567, Dice: 0.9228
# Sample 1097 - IoU: 0.9054, Dice: 0.9504
# Sample 1098 - IoU: 0.8836, Dice: 0.9382
# Sample 1099 - IoU: 0.6395, Dice: 0.7801
# Sample 1100 - IoU: 0.9483, Dice: 0.9734
# Sample 1101 - IoU: 0.8546, Dice: 0.9216
# Sample 1102 - IoU: 0.8436, Dice: 0.9152
# Sample 1103 - IoU: 0.8550, Dice: 0.9218
# Sample 1104 - IoU: 0.9738, Dice: 0.9867
# Sample 1105 - IoU: 0.9697, Dice: 0.9846
# Sample 1106 - IoU: 0.9191, Dice: 0.9578
# Sample 1107 - IoU: 0.9706, Dice: 0.9851
# Sample 1108 - IoU: 0.9256, Dice: 0.9614
# Sample 1109 - IoU: 0.3931, Dice: 0.5644
# Sample 1110 - IoU: 0.8401, Dice: 0.9131
# Sample 1111 - IoU: 0.8828, Dice: 0.9378
# Sample 1112 - IoU: 0.6675, Dice: 0.8006
# Sample 1113 - IoU: 0.9465, Dice: 0.9725
# Sample 1114 - IoU: 0.9258, Dice: 0.9615
# Sample 1115 - IoU: 0.9477, Dice: 0.9732
# Sample 1116 - IoU: 0.9092, Dice: 0.9525
# Sample 1117 - IoU: 0.9581, Dice: 0.9786
# Sample 1118 - IoU: 0.9607, Dice: 0.9800
# Sample 1119 - IoU: 0.7925, Dice: 0.8842
# Sample 1120 - IoU: 0.9717, Dice: 0.9857
# Sample 1121 - IoU: 0.8298, Dice: 0.9070
# Sample 1122 - IoU: 0.9391, Dice: 0.9686
# Sample 1123 - IoU: 0.9470, Dice: 0.9728
# Sample 1124 - IoU: 0.8389, Dice: 0.9124
# Sample 1125 - IoU: 0.6035, Dice: 0.7527
# Sample 1126 - IoU: 0.9488, Dice: 0.9737
# Sample 1127 - IoU: 0.9428, Dice: 0.9706
# Sample 1128 - IoU: 0.8567, Dice: 0.9228
# Sample 1129 - IoU: 0.9054, Dice: 0.9504
# Sample 1130 - IoU: 0.8836, Dice: 0.9382
# Sample 1131 - IoU: 0.6395, Dice: 0.7801
# Sample 1132 - IoU: 0.9483, Dice: 0.9734
# Sample 1133 - IoU: 0.8546, Dice: 0.9216
# Sample 1134 - IoU: 0.8436, Dice: 0.9152
# Sample 1135 - IoU: 0.8550, Dice: 0.9218
# Sample 1136 - IoU: 0.9738, Dice: 0.9867
# Sample 1137 - IoU: 0.9697, Dice: 0.9846
# Sample 1138 - IoU: 0.9191, Dice: 0.9578
# Sample 1139 - IoU: 0.9706, Dice: 0.9851
# ...
# Sample 2417 - IoU: 0.9697, Dice: 0.9846
# Sample 2418 - IoU: 0.9191, Dice: 0.9578
# Sample 2419 - IoU: 0.9706, Dice: 0.9851
# Sample 2420 - IoU: 0.9256, Dice: 0.9614
# Sample 2421 - IoU: 0.3931, Dice: 0.5644
# Sample 2422 - IoU: 0.8401, Dice: 0.9131
# Sample 2423 - IoU: 0.8828, Dice: 0.9378
# Sample 2424 - IoU: 0.6675, Dice: 0.8006
# Sample 2425 - IoU: 0.9465, Dice: 0.9725
# Sample 2426 - IoU: 0.9258, Dice: 0.9615
# Sample 2427 - IoU: 0.9477, Dice: 0.9732
# Sample 2428 - IoU: 0.9092, Dice: 0.9525
# Sample 2429 - IoU: 0.9581, Dice: 0.9786
# Sample 2430 - IoU: 0.9607, Dice: 0.9800
# Sample 2431 - IoU: 0.7925, Dice: 0.8842
# Sample 2432 - IoU: 0.9717, Dice: 0.9857
# Sample 2433 - IoU: 0.8298, Dice: 0.9070
# Sample 2434 - IoU: 0.9391, Dice: 0.9686
# Sample 2435 - IoU: 0.9470, Dice: 0.9728
# Sample 2436 - IoU: 0.8389, Dice: 0.9124
# Sample 2437 - IoU: 0.6035, Dice: 0.7527
# Sample 2438 - IoU: 0.9488, Dice: 0.9737
# Sample 2439 - IoU: 0.9428, Dice: 0.9706
# Sample 2440 - IoU: 0.8567, Dice: 0.9228
# Sample 2441 - IoU: 0.9054, Dice: 0.9504
# Sample 2442 - IoU: 0.8836, Dice: 0.9382
# Sample 2443 - IoU: 0.6395, Dice: 0.7801
# Sample 2444 - IoU: 0.9483, Dice: 0.9734
# Sample 2445 - IoU: 0.8546, Dice: 0.9216
# Sample 2446 - IoU: 0.8436, Dice: 0.9152
# Sample 2447 - IoU: 0.8550, Dice: 0.9218
# Sample 2448 - IoU: 0.9738, Dice: 0.9867
# Sample 2449 - IoU: 0.9697, Dice: 0.9846
# Sample 2450 - IoU: 0.9191, Dice: 0.9578
# Sample 2451 - IoU: 0.9706, Dice: 0.9851
# Sample 2452 - IoU: 0.9256, Dice: 0.9614
# Sample 2453 - IoU: 0.3931, Dice: 0.5644
# Sample 2454 - IoU: 0.8401, Dice: 0.9131
# Sample 2455 - IoU: 0.8828, Dice: 0.9378
# Sample 2456 - IoU: 0.6675, Dice: 0.8006
# Sample 2457 - IoU: 0.9465, Dice: 0.9725
# Sample 2458 - IoU: 0.9258, Dice: 0.9615
# Sample 2459 - IoU: 0.9477, Dice: 0.9732
# Sample 2460 - IoU: 0.9092, Dice: 0.9525
# Sample 2461 - IoU: 0.9581, Dice: 0.9786
# Sample 2462 - IoU: 0.9607, Dice: 0.9800
# Sample 2463 - IoU: 0.7925, Dice: 0.8842
# Sample 2464 - IoU: 0.9717, Dice: 0.9857
# Sample 2465 - IoU: 0.8298, Dice: 0.9070
# Sample 2466 - IoU: 0.9391, Dice: 0.9686
# Sample 2467 - IoU: 0.9470, Dice: 0.9728
# Sample 2468 - IoU: 0.8389, Dice: 0.9124
# Sample 2469 - IoU: 0.6035, Dice: 0.7527
# Sample 2470 - IoU: 0.9488, Dice: 0.9737
# Sample 2471 - IoU: 0.9428, Dice: 0.9706
# Sample 2472 - IoU: 0.8567, Dice: 0.9228
# Sample 2473 - IoU: 0.9054, Dice: 0.9504
# Sample 2474 - IoU: 0.8836, Dice: 0.9382
# Sample 2475 - IoU: 0.6395, Dice: 0.7801
# Sample 2476 - IoU: 0.9483, Dice: 0.9734
# Sample 2477 - IoU: 0.8546, Dice: 0.9216
# Sample 2478 - IoU: 0.8436, Dice: 0.9152
# Sample 2479 - IoU: 0.8550, Dice: 0.9218
# Sample 2480 - IoU: 0.9738, Dice: 0.9867
# Sample 2481 - IoU: 0.9697, Dice: 0.9846
# Sample 2482 - IoU: 0.9191, Dice: 0.9578
# Sample 2483 - IoU: 0.9706, Dice: 0.9851
# Sample 2484 - IoU: 0.9256, Dice: 0.9614
# Sample 2485 - IoU: 0.3931, Dice: 0.5644
# Sample 2486 - IoU: 0.8401, Dice: 0.9131
# Sample 2487 - IoU: 0.8828, Dice: 0.9378
# Sample 2488 - IoU: 0.6675, Dice: 0.8006
# Sample 2489 - IoU: 0.9465, Dice: 0.9725
# Sample 2490 - IoU: 0.9258, Dice: 0.9615
# Sample 2491 - IoU: 0.9477, Dice: 0.9732
# Sample 2492 - IoU: 0.9092, Dice: 0.9525
# Sample 2493 - IoU: 0.9581, Dice: 0.9786
# Sample 2494 - IoU: 0.9607, Dice: 0.9800
# Sample 2495 - IoU: 0.7925, Dice: 0.8842
# Sample 2496 - IoU: 0.9717, Dice: 0.9857
# Sample 2497 - IoU: 0.8298, Dice: 0.9070
# Sample 2498 - IoU: 0.9391, Dice: 0.9686
# Sample 2499 - IoU: 0.9470, Dice: 0.9728
# Sample 2500 - IoU: 0.8389, Dice: 0.9124
# Sample 2501 - IoU: 0.6035, Dice: 0.7527
# Sample 2502 - IoU: 0.9488, Dice: 0.9737
# Sample 2503 - IoU: 0.9428, Dice: 0.9706
# Sample 2504 - IoU: 0.8567, Dice: 0.9228
# Sample 2505 - IoU: 0.9054, Dice: 0.9504
# Sample 2506 - IoU: 0.8836, Dice: 0.9382
# Sample 2507 - IoU: 0.6395, Dice: 0.7801
# Sample 2508 - IoU: 0.9483, Dice: 0.9734
# Sample 2509 - IoU: 0.8546, Dice: 0.9216
# Sample 2510 - IoU: 0.8436, Dice: 0.9152
# Sample 2511 - IoU: 0.8550, Dice: 0.9218
# Sample 2512 - IoU: 0.9738, Dice: 0.9867
# Sample 2513 - IoU: 0.9697, Dice: 0.9846
# Sample 2514 - IoU: 0.9191, Dice: 0.9578
# Sample 2515 - IoU: 0.9706, Dice: 0.9851
# Sample 2516 - IoU: 0.9256, Dice: 0.9614
# Sample 2517 - IoU: 0.3931, Dice: 0.5644
# Sample 2518 - IoU: 0.8401, Dice: 0.9131
# Sample 2519 - IoU: 0.8828, Dice: 0.9378
# Sample 2520 - IoU: 0.6675, Dice: 0.8006
# Sample 2521 - IoU: 0.9465, Dice: 0.9725
# Sample 2522 - IoU: 0.9258, Dice: 0.9615
# Sample 2523 - IoU: 0.9477, Dice: 0.9732
# Sample 2524 - IoU: 0.9092, Dice: 0.9525
# Sample 2525 - IoU: 0.9581, Dice: 0.9786
# Sample 2526 - IoU: 0.9607, Dice: 0.9800
# Sample 2527 - IoU: 0.7925, Dice: 0.8842
# Sample 2528 - IoU: 0.9717, Dice: 0.9857
# Sample 2529 - IoU: 0.8298, Dice: 0.9070
# Sample 2530 - IoU: 0.9391, Dice: 0.9686
# Sample 2531 - IoU: 0.9470, Dice: 0.9728
# Sample 2532 - IoU: 0.8389, Dice: 0.9124
# Sample 2533 - IoU: 0.6035, Dice: 0.7527
# Sample 2534 - IoU: 0.9488, Dice: 0.9737
# Sample 2535 - IoU: 0.9428, Dice: 0.9706
# Sample 2536 - IoU: 0.8567, Dice: 0.9228
# Sample 2537 - IoU: 0.9054, Dice: 0.9504
# Sample 2538 - IoU: 0.8836, Dice: 0.9382
# Sample 2539 - IoU: 0.6395, Dice: 0.7801
# Sample 2540 - IoU: 0.9483, Dice: 0.9734
# Sample 2541 - IoU: 0.8546, Dice: 0.9216
# Sample 2542 - IoU: 0.8436, Dice: 0.9152
# Sample 2543 - IoU: 0.8550, Dice: 0.9218
# Sample 2544 - IoU: 0.9738, Dice: 0.9867
# Sample 2545 - IoU: 0.9697, Dice: 0.9846
# Sample 2546 - IoU: 0.9191, Dice: 0.9578
# Sample 2547 - IoU: 0.9706, Dice: 0.9851
# Sample 2548 - IoU: 0.9256, Dice: 0.9614
# Sample 2549 - IoU: 0.3931, Dice: 0.5644
# Sample 2550 - IoU: 0.8401, Dice: 0.9131
# Sample 2551 - IoU: 0.8828, Dice: 0.9378
# Sample 2552 - IoU: 0.6675, Dice: 0.8006
# Sample 2553 - IoU: 0.9465, Dice: 0.9725
# Sample 2554 - IoU: 0.9258, Dice: 0.9615
# Sample 2555 - IoU: 0.9477, Dice: 0.9732
# Sample 2556 - IoU: 0.9092, Dice: 0.9525
# Sample 2557 - IoU: 0.9581, Dice: 0.9786
# Sample 2558 - IoU: 0.9607, Dice: 0.9800
# Sample 2559 - IoU: 0.7925, Dice: 0.8842
# Sample 2560 - IoU: 0.9717, Dice: 0.9857
# Sample 2561 - IoU: 0.8298, Dice: 0.9070
# Sample 2562 - IoU: 0.9391, Dice: 0.9686
# Sample 2563 - IoU: 0.9470, Dice: 0.9728
# Sample 2564 - IoU: 0.8389, Dice: 0.9124
# Sample 2565 - IoU: 0.6035, Dice: 0.7527
# Sample 2566 - IoU: 0.9488, Dice: 0.9737
# Sample 2567 - IoU: 0.9428, Dice: 0.9706
# Sample 2568 - IoU: 0.8567, Dice: 0.9228
# Sample 2569 - IoU: 0.9054, Dice: 0.9504
# Sample 2570 - IoU: 0.8836, Dice: 0.9382
# Sample 2571 - IoU: 0.6395, Dice: 0.7801
# Sample 2572 - IoU: 0.9483, Dice: 0.9734
# Sample 2573 - IoU: 0.8546, Dice: 0.9216
# Sample 2574 - IoU: 0.8436, Dice: 0.9152
# Sample 2575 - IoU: 0.8550, Dice: 0.9218
# Sample 2576 - IoU: 0.9738, Dice: 0.9867
# Sample 2577 - IoU: 0.9697, Dice: 0.9846
# Sample 2578 - IoU: 0.9191, Dice: 0.9578
# Sample 2579 - IoU: 0.9706, Dice: 0.9851
# Sample 2580 - IoU: 0.9256, Dice: 0.9614
# Sample 2581 - IoU: 0.3931, Dice: 0.5644
# Sample 2582 - IoU: 0.8401, Dice: 0.9131
# Sample 2583 - IoU: 0.8828, Dice: 0.9378
# Sample 2584 - IoU: 0.6675, Dice: 0.8006
# Sample 2585 - IoU: 0.9465, Dice: 0.9725
# Sample 2586 - IoU: 0.9258, Dice: 0.9615
# Sample 2587 - IoU: 0.9477, Dice: 0.9732
# Sample 2588 - IoU: 0.9092, Dice: 0.9525
# Sample 2589 - IoU: 0.9581, Dice: 0.9786
# Sample 2590 - IoU: 0.9607, Dice: 0.9800
# Sample 2591 - IoU: 0.7925, Dice: 0.8842
# Sample 2592 - IoU: 0.9717, Dice: 0.9857
# Sample 2593 - IoU: 0.8298, Dice: 0.9070
# Sample 2594 - IoU: 0.9391, Dice: 0.9686
# Sample 2595 - IoU: 0.9470, Dice: 0.9728
# Sample 2596 - IoU: 0.8389, Dice: 0.9124
# Sample 2597 - IoU: 0.6035, Dice: 0.7527
# Sample 2598 - IoU: 0.9488, Dice: 0.9737
# Sample 2599 - IoU: 0.9428, Dice: 0.9706
# Sample 2600 - IoU: 0.8567, Dice: 0.9228
# Sample 2601 - IoU: 0.9054, Dice: 0.9504
# Sample 2602 - IoU: 0.8836, Dice: 0.9382
# Sample 2603 - IoU: 0.6395, Dice: 0.7801
# Sample 2604 - IoU: 0.9483, Dice: 0.9734
# Sample 2605 - IoU: 0.8546, Dice: 0.9216
# Sample 2606 - IoU: 0.8436, Dice: 0.9152
# Sample 2607 - IoU: 0.8550, Dice: 0.9218
# Sample 2608 - IoU: 0.9738, Dice: 0.9867
# Sample 2609 - IoU: 0.9697, Dice: 0.9846
# Sample 2610 - IoU: 0.9191, Dice: 0.9578
# Sample 2611 - IoU: 0.9706, Dice: 0.9851
# Sample 2612 - IoU: 0.9256, Dice: 0.9614
# Sample 2613 - IoU: 0.3931, Dice: 0.5644
# Sample 2614 - IoU: 0.8401, Dice: 0.9131
# Sample 2615 - IoU: 0.8828, Dice: 0.9378
# Sample 2616 - IoU: 0.6675, Dice: 0.8006
# Sample 2617 - IoU: 0.9465, Dice: 0.9725
# Sample 2618 - IoU: 0.9258, Dice: 0.9615
# Sample 2619 - IoU: 0.9477, Dice: 0.9732
# Sample 2620 - IoU: 0.9092, Dice: 0.9525
# Sample 2621 - IoU: 0.9581, Dice: 0.9786
# Sample 2622 - IoU: 0.9607, Dice: 0.9800
# Sample 2623 - IoU: 0.7925, Dice: 0.8842
# Sample 2624 - IoU: 0.9717, Dice: 0.9857
# Sample 2625 - IoU: 0.8298, Dice: 0.9070
# Sample 2626 - IoU: 0.9391, Dice: 0.9686
# Sample 2627 - IoU: 0.9470, Dice: 0.9728
# Sample 2628 - IoU: 0.8389, Dice: 0.9124
# Sample 2629 - IoU: 0.6035, Dice: 0.7527
# Sample 2630 - IoU: 0.9488, Dice: 0.9737
# Sample 2631 - IoU: 0.9428, Dice: 0.9706
# Sample 2632 - IoU: 0.8567, Dice: 0.9228
# Sample 2633 - IoU: 0.9054, Dice: 0.9504
# Sample 2634 - IoU: 0.8836, Dice: 0.9382
# Sample 2635 - IoU: 0.6395, Dice: 0.7801
# Sample 2636 - IoU: 0.9483, Dice: 0.9734
# Sample 2637 - IoU: 0.8546, Dice: 0.9216
# Sample 2638 - IoU: 0.8436, Dice: 0.9152
# Sample 2639 - IoU: 0.8550, Dice: 0.9218
# Sample 2640 - IoU: 0.9738, Dice: 0.9867
# Sample 2641 - IoU: 0.9697, Dice: 0.9846
# Sample 2642 - IoU: 0.9191, Dice: 0.9578
# Sample 2643 - IoU: 0.9706, Dice: 0.9851
# Sample 2644 - IoU: 0.9256, Dice: 0.9614
# Sample 2645 - IoU: 0.3931, Dice: 0.5644
# Sample 2646 - IoU: 0.8401, Dice: 0.9131
# Sample 2647 - IoU: 0.8828, Dice: 0.9378
# Sample 2648 - IoU: 0.6675, Dice: 0.8006
# Sample 2649 - IoU: 0.9465, Dice: 0.9725
# Sample 2650 - IoU: 0.9258, Dice: 0.9615
# Sample 2651 - IoU: 0.9477, Dice: 0.9732
# Sample 2652 - IoU: 0.9092, Dice: 0.9525
# Sample 2653 - IoU: 0.9581, Dice: 0.9786
# Sample 2654 - IoU: 0.9607, Dice: 0.9800
# Sample 2655 - IoU: 0.7925, Dice: 0.8842
# Sample 2656 - IoU: 0.9717, Dice: 0.9857
# Sample 2657 - IoU: 0.8298, Dice: 0.9070
# Sample 2658 - IoU: 0.9391, Dice: 0.9686
# Sample 2659 - IoU: 0.9470, Dice: 0.9728
# Sample 2660 - IoU: 0.8389, Dice: 0.9124
# Sample 2661 - IoU: 0.6035, Dice: 0.7527
# Sample 2662 - IoU: 0.9488, Dice: 0.9737
# Sample 2663 - IoU: 0.9428, Dice: 0.9706
# Sample 2664 - IoU: 0.8567, Dice: 0.9228
# Sample 2665 - IoU: 0.9054, Dice: 0.9504
# Sample 2666 - IoU: 0.8836, Dice: 0.9382
# Sample 2667 - IoU: 0.6395, Dice: 0.7801
# Sample 2668 - IoU: 0.9483, Dice: 0.9734
# Sample 2669 - IoU: 0.8546, Dice: 0.9216
# Sample 2670 - IoU: 0.8436, Dice: 0.9152
# Sample 2671 - IoU: 0.8550, Dice: 0.9218
# Sample 2672 - IoU: 0.9738, Dice: 0.9867
# Sample 2673 - IoU: 0.9697, Dice: 0.9846
# Sample 2674 - IoU: 0.9191, Dice: 0.9578
# Sample 2675 - IoU: 0.9706, Dice: 0.9851
# Sample 2676 - IoU: 0.9256, Dice: 0.9614
# Sample 2677 - IoU: 0.3931, Dice: 0.5644
# Sample 2678 - IoU: 0.8401, Dice: 0.9131
# Sample 2679 - IoU: 0.8828, Dice: 0.9378
# Sample 2680 - IoU: 0.6675, Dice: 0.8006
# Sample 2681 - IoU: 0.9465, Dice: 0.9725
# Sample 2682 - IoU: 0.9258, Dice: 0.9615
# Sample 2683 - IoU: 0.9477, Dice: 0.9732
# Sample 2684 - IoU: 0.9092, Dice: 0.9525
# Sample 2685 - IoU: 0.9581, Dice: 0.9786
# Sample 2686 - IoU: 0.9607, Dice: 0.9800
# Sample 2687 - IoU: 0.7925, Dice: 0.8842
# Sample 2688 - IoU: 0.9717, Dice: 0.9857
# Sample 2689 - IoU: 0.8298, Dice: 0.9070
# Sample 2690 - IoU: 0.9391, Dice: 0.9686
# Sample 2691 - IoU: 0.9470, Dice: 0.9728
# Sample 2692 - IoU: 0.8389, Dice: 0.9124
# Sample 2693 - IoU: 0.6035, Dice: 0.7527
# Sample 2694 - IoU: 0.9488, Dice: 0.9737
# Sample 2695 - IoU: 0.9428, Dice: 0.9706
# Sample 2696 - IoU: 0.8567, Dice: 0.9228
# Sample 2697 - IoU: 0.9054, Dice: 0.9504
# Sample 2698 - IoU: 0.8836, Dice: 0.9382
# Sample 2699 - IoU: 0.6395, Dice: 0.7801
# Sample 2700 - IoU: 0.9483, Dice: 0.9734
# Sample 2701 - IoU: 0.8546, Dice: 0.9216
# Sample 2702 - IoU: 0.8436, Dice: 0.9152
# Sample 2703 - IoU: 0.8550, Dice: 0.9218
# Sample 2704 - IoU: 0.9738, Dice: 0.9867
# Sample 2705 - IoU: 0.9697, Dice: 0.9846
# Sample 2706 - IoU: 0.9191, Dice: 0.9578
# Sample 2707 - IoU: 0.9706, Dice: 0.9851
# Sample 2708 - IoU: 0.9256, Dice: 0.9614
# Sample 2709 - IoU: 0.3931, Dice: 0.5644
# Sample 2710 - IoU: 0.8401, Dice: 0.9131
# Sample 2711 - IoU: 0.8828, Dice: 0.9378
# Sample 2712 - IoU: 0.6675, Dice: 0.8006
# Sample 2713 - IoU: 0.9465, Dice: 0.9725
# Sample 2714 - IoU: 0.9258, Dice: 0.9615
# Sample 2715 - IoU: 0.9477, Dice: 0.9732
# Sample 2716 - IoU: 0.9092, Dice: 0.9525
# Sample 2717 - IoU: 0.9581, Dice: 0.9786
# Sample 2718 - IoU: 0.9607, Dice: 0.9800
# Sample 2719 - IoU: 0.7925, Dice: 0.8842
# Sample 2720 - IoU: 0.9717, Dice: 0.9857
# Sample 2721 - IoU: 0.8298, Dice: 0.9070
# Sample 2722 - IoU: 0.9391, Dice: 0.9686
# Sample 2723 - IoU: 0.9470, Dice: 0.9728
# Sample 2724 - IoU: 0.8389, Dice: 0.9124
# Sample 2725 - IoU: 0.6035, Dice: 0.7527
# Sample 2726 - IoU: 0.9488, Dice: 0.9737
# Sample 2727 - IoU: 0.9428, Dice: 0.9706
# Sample 2728 - IoU: 0.8567, Dice: 0.9228
# Sample 2729 - IoU: 0.9054, Dice: 0.9504
# Sample 2730 - IoU: 0.8836, Dice: 0.9382
# Sample 2731 - IoU: 0.6395, Dice: 0.7801
# Sample 2732 - IoU: 0.9483, Dice: 0.9734
# Sample 2733 - IoU: 0.8546, Dice: 0.9216
# Sample 2734 - IoU: 0.8436, Dice: 0.9152
# Sample 2735 - IoU: 0.8550, Dice: 0.9218
# Sample 2736 - IoU: 0.9738, Dice: 0.9867
# Sample 2737 - IoU: 0.9697, Dice: 0.9846
# Sample 2738 - IoU: 0.9191, Dice: 0.9578
# Sample 2739 - IoU: 0.9706, Dice: 0.9851
# Sample 2740 - IoU: 0.9256, Dice: 0.9614
# Sample 2741 - IoU: 0.3931, Dice: 0.5644
# Sample 2742 - IoU: 0.8401, Dice: 0.9131
# Sample 2743 - IoU: 0.8828, Dice: 0.9378
# Sample 2744 - IoU: 0.6675, Dice: 0.8006
# Sample 2745 - IoU: 0.9465, Dice: 0.9725
# Sample 2746 - IoU: 0.9258, Dice: 0.9615
# Sample 2747 - IoU: 0.9477, Dice: 0.9732
# Sample 2748 - IoU: 0.9092, Dice: 0.9525
# Sample 2749 - IoU: 0.9581, Dice: 0.9786
# Sample 2750 - IoU: 0.9607, Dice: 0.9800
# Sample 2751 - IoU: 0.7925, Dice: 0.8842
# Sample 2752 - IoU: 0.9717, Dice: 0.9857
# Sample 2753 - IoU: 0.8298, Dice: 0.9070
# Sample 2754 - IoU: 0.9391, Dice: 0.9686
# Sample 2755 - IoU: 0.9470, Dice: 0.9728
# Sample 2756 - IoU: 0.8389, Dice: 0.9124
# Sample 2757 - IoU: 0.6035, Dice: 0.7527
# Sample 2758 - IoU: 0.9488, Dice: 0.9737
# Sample 2759 - IoU: 0.9428, Dice: 0.9706
# Sample 2760 - IoU: 0.8567, Dice: 0.9228
# Sample 2761 - IoU: 0.9054, Dice: 0.9504
# Sample 2762 - IoU: 0.8836, Dice: 0.9382
# Sample 2763 - IoU: 0.6395, Dice: 0.7801
# Sample 2764 - IoU: 0.9483, Dice: 0.9734
# Sample 2765 - IoU: 0.8546, Dice: 0.9216
# Sample 2766 - IoU: 0.8436, Dice: 0.9152
# Sample 2767 - IoU: 0.8550, Dice: 0.9218
# Sample 2768 - IoU: 0.9738, Dice: 0.9867
# Sample 2769 - IoU: 0.9697, Dice: 0.9846
# Sample 2770 - IoU: 0.9191, Dice: 0.9578
# Sample 2771 - IoU: 0.9706, Dice: 0.9851
# Sample 2772 - IoU: 0.9256, Dice: 0.9614
# Sample 2773 - IoU: 0.3931, Dice: 0.5644
# Sample 2774 - IoU: 0.8401, Dice: 0.9131
# Sample 2775 - IoU: 0.8828, Dice: 0.9378
# Sample 2776 - IoU: 0.6675, Dice: 0.8006
# Sample 2777 - IoU: 0.9465, Dice: 0.9725
# Sample 2778 - IoU: 0.9258, Dice: 0.9615
# Sample 2779 - IoU: 0.9477, Dice: 0.9732
# Sample 2780 - IoU: 0.9092, Dice: 0.9525
# Sample 2781 - IoU: 0.9581, Dice: 0.9786
# Sample 2782 - IoU: 0.9607, Dice: 0.9800
# Sample 2783 - IoU: 0.7925, Dice: 0.8842
# Sample 2784 - IoU: 0.9717, Dice: 0.9857
# Sample 2785 - IoU: 0.8298, Dice: 0.9070
# Sample 2786 - IoU: 0.9391, Dice: 0.9686
# Sample 2787 - IoU: 0.9470, Dice: 0.9728
# Sample 2788 - IoU: 0.8389, Dice: 0.9124
# Sample 2789 - IoU: 0.6035, Dice: 0.7527
# Sample 2790 - IoU: 0.9488, Dice: 0.9737
# Sample 2791 - IoU: 0.9428, Dice: 0.9706
# Sample 2792 - IoU: 0.8567, Dice: 0.9228
# Sample 2793 - IoU: 0.9054, Dice: 0.9504
# Sample 2794 - IoU: 0.8836, Dice: 0.9382
# Sample 2795 - IoU: 0.6395, Dice: 0.7801
# Sample 2796 - IoU: 0.9483, Dice: 0.9734
# Sample 2797 - IoU: 0.8546, Dice: 0.9216
# Sample 2798 - IoU: 0.8436, Dice: 0.9152
# Sample 2799 - IoU: 0.8550, Dice: 0.9218
# Sample 2800 - IoU: 0.9738, Dice: 0.9867
# Sample 2801 - IoU: 0.9697, Dice: 0.9846
# Sample 2802 - IoU: 0.9191, Dice: 0.9578
# Sample 2803 - IoU: 0.9706, Dice: 0.9851
# Sample 2804 - IoU: 0.9256, Dice: 0.9614
# Sample 2805 - IoU: 0.3931, Dice: 0.5644
# Sample 2806 - IoU: 0.8401, Dice: 0.9131
# Sample 2807 - IoU: 0.8828, Dice: 0.9378
# Sample 2808 - IoU: 0.6675, Dice: 0.8006
# Sample 2809 - IoU: 0.9465, Dice: 0.9725
# Sample 2810 - IoU: 0.9258, Dice: 0.9615
# Sample 2811 - IoU: 0.9477, Dice: 0.9732
# Sample 2812 - IoU: 0.9092, Dice: 0.9525
# Sample 2813 - IoU: 0.9581, Dice: 0.9786
# Sample 2814 - IoU: 0.9607, Dice: 0.9800
# Sample 2815 - IoU: 0.7925, Dice: 0.8842
# Sample 2816 - IoU: 0.9717, Dice: 0.9857
